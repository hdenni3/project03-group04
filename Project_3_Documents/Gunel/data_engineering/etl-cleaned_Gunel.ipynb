# %%
# dependencies
import chardet
import pandas as pd
import os 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
import plotly.express as px


# API
import requests
import json

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

# %%
# Load in file
# Store filepath in a variable
YOUTUBE_PATH = "Resources/global_youtube.csv"

# %%
with open(YOUTUBE_PATH, 'rb') as csv_file:
    raw_content = csv_file.read()
    chardet_result = chardet.detect(raw_content)
print(chardet_result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7289153199558486, 'language': ''}

# %%
# Read and display the CSV with Pandas
df = pd.read_csv(YOUTUBE_PATH, encoding=chardet_result['encoding'])
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
#  10  video_views_rank                         994 non-null    float64
#  11  country_rank                             879 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  995 non-null    float64
#  15  highest_monthly_earnings                 995 non-null    float64
#  16  lowest_yearly_earnings                   995 non-null    float64
#  17  highest_yearly_earnings                  995 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    float64
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  872 non-null    float64
#  23  Population                               872 non-null    float64
#  24  Unemployment rate                        872 non-null    float64
#  25  Urban_population                         872 non-null    float64
#  26  Latitude                                 872 non-null    float64
#  27  Longitude                                872 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 217.8+ KB

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1232.244746        1944.386561                      4.163782e+08
# min        1.000000           1.000000                      1.000000e+00
# 25%       11.000000          27.000000                      2.013750e+07
# 50%       51.000000          65.500000                      6.408500e+07
# 75%      123.000000         139.750000                      1.688265e+08
# max     7741.000000        7741.000000                      6.589000e+09
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count               995.000000              9.950000e+02  ...
# mean              36886.148281              5.898078e+05  ...
# std               71858.724092              1.148622e+06  ...
# min                   0.000000              0.000000e+00  ...
# 25%                2700.000000              4.350000e+04  ...
# 50%               13300.000000              2.127000e+05  ...
# 75%               37900.000000              6.068000e+05  ...
# max              850900.000000              1.360000e+07  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count             9.950000e+02                  6.580000e+02    990.000000
# mean              7.081814e+06                  3.490791e+05   2012.630303
# std               1.379704e+07                  6.143554e+05      4.512503
# min               0.000000e+00                  1.000000e+00   1970.000000
# 25%               5.217500e+05                  1.000000e+05   2009.000000
# 50%               2.600000e+06                  2.000000e+05   2013.000000
# 75%               7.300000e+06                  4.000000e+05   2016.000000
# max               1.634000e+08                  8.000000e+06   2022.000000
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count    990.000000                               872.000000  8.720000e+02
# mean      15.746465                                63.627752  4.303873e+08
# std        8.777520                                26.106893  4.727947e+08
# min        1.000000                                 7.600000  2.025060e+05
# 25%        8.000000                                36.300000  8.335541e+07
# 50%       16.000000                                68.000000  3.282395e+08
# 75%       23.000000                                88.200000  3.282395e+08
# max       31.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude
# count         872.000000      8.720000e+02  872.000000  872.000000
# mean            9.279278      2.242150e+08   26.632783  -14.128146
# std             4.888354      1.546874e+08   20.560533   84.760809
# min             0.750000      3.558800e+04  -38.416097 -172.104629
# 25%             5.270000      5.590832e+07   20.593684  -95.712891
# 50%             9.365000      2.706630e+08   37.090240  -51.925280
# 75%            14.700000      2.706630e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.924110  138.252924
#
# [8 rows x 21 columns]

# %%
#remove special characters
pattern = r'[^a-zA-Z0-9\s.,!?&\'-]'

#Youtuber feature
df['Youtuber'] = df['Youtuber'].apply(lambda x: re.sub(pattern, '', x)) 
df['Youtuber'] = df['Youtuber'].str.strip() 
df['Youtuber'] = df['Youtuber'].str.lstrip('- ')

# %%
#Remove data null in column 'Created Year'
df = df.dropna(subset= ['created_year'])
df['created_year'] = df['created_year'].astype('object')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 990 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     990 non-null    int64
#  1   Youtuber                                 990 non-null    object
#  2   subscribers                              990 non-null    int64
#  3   video views                              990 non-null    float64
#  4   category                                 944 non-null    object
#  5   Title                                    990 non-null    object
#  6   uploads                                  990 non-null    int64
#  7   Country                                  870 non-null    object
#  8   Abbreviation                             870 non-null    object
#  9   channel_type                             963 non-null    object
#  10  video_views_rank                         990 non-null    float64
#  11  country_rank                             876 non-null    float64
#  12  channel_type_rank                        961 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  990 non-null    float64
#  15  highest_monthly_earnings                 990 non-null    float64
#  16  lowest_yearly_earnings                   990 non-null    float64
#  17  highest_yearly_earnings                  990 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    object
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  869 non-null    float64
#  23  Population                               869 non-null    float64
#  24  Unemployment rate                        869 non-null    float64
#  25  Urban_population                         869 non-null    float64
#  26  Latitude                                 869 non-null    float64
#  27  Longitude                                869 non-null    float64
# dtypes: float64(17), int64(3), object(8)
# memory usage: 224.3+ KB

# %%
df['created_year'].unique()
# Out:
# array([2006.0, 2012.0, 2013.0, 2015.0, 2010.0, 2016.0, 2018.0, 2014.0,
#        2007.0, 2020.0, 2008.0, 2005.0, 2011.0, 2009.0, 2017.0, 2021.0,
#        1970.0, 2019.0, 2022.0], dtype=object)

# %%
#Check Created Year is 1970
df[df['created_year'] == 1970]
# Out:
#      rank Youtuber  subscribers   video views         category    Title  \
# 101   102  YouTube     36300000  3.010785e+09  News & Politics  YouTube
#
#      uploads        Country Abbreviation   channel_type  ...  \
# 101      744  United States           US  Entertainment  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 101                      300000.0        1970.0            Jan           1.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 101                                     88.2  328239523.0               14.7
#
#      Urban_population  Latitude  Longitude
# 101       270663028.0  37.09024 -95.712891
#
# [1 rows x 28 columns]

# %%
df[df['Youtuber'] == 'YouTube'] = df[df['Youtuber'] == 'YouTube'].replace(1970, 2005)
df[df['Youtuber'] == 'YouTube']
# Out:
#      rank Youtuber  subscribers   video views         category    Title  \
# 101   102  YouTube     36300000  3.010785e+09  News & Politics  YouTube
#
#      uploads        Country Abbreviation   channel_type  ...  \
# 101      744  United States           US  Entertainment  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 101                      300000.0          2005            Jan           1.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 101                                     88.2  328239523.0               14.7
#
#      Urban_population  Latitude  Longitude
# 101       270663028.0  37.09024 -95.712891
#
# [1 rows x 28 columns]

# %%
#After remomved characters, we will some blanks data in column 'Youtuber'. Let's check it
blanks_data_youtuber = df[df['Youtuber'] == '']
blanks_data_youtuber
# Out:
#      rank Youtuber  subscribers   video views          category  \
# 64     65              43200000  3.645873e+10  Film & Animation
# 161   162              30400000  1.799996e+10               NaN
# 433   434              19000000  4.924054e+09         Education
# 447   448              18800000  9.594189e+09     Entertainment
# 561   562              16500000  2.440934e+09     Entertainment
# 606   607              15900000  1.845330e+09    People & Blogs
# 632   633              15500000  8.265130e+09             Shows
# 700   701              14900000  4.390980e+05    People & Blogs
# 707   708              14800000  7.018015e+09     Howto & Style
# 714   715              14700000  2.230986e+09     Entertainment
# 752   753              14400000  6.001543e+08     Entertainment
# 784   785              14100000  3.920221e+09     Entertainment
# 795   796              14000000  7.719743e+09            Gaming
# 810   811              13900000  8.451755e+09               NaN
# 866   867              13300000  6.482687e+09    People & Blogs
# 920   921              12900000  5.585085e+09             Shows
#
#                                          Title  uploads        Country  \
# 64                  ýýýýýýýý ýý ýýýýýýýýýýýýýý     1478         Russia
# 161  ýýýýýýýýýýýýýýý ýýýýýý ýýýýýýýýýýýýýýýýýý      532  United States
# 433                        ýýýýýýýýýýýýýý ýýýý       60  United States
# 447                     ýýýýýýýýýýýýýýýýýýýýýý      530        Ukraine
# 561            ýýýýýýýý ýýýýýýýýýýýýýýýýýýýýýý      421  United States
# 606                              Kung Fu Padla        0         Russia
# 632                       ýýýýýýýý ýý ýýýýýýýý     1021   Saudi Arabia
# 700                                     ýýýýýý        1         Russia
# 707                          ýýýýýýýý ýýýýýýýý     2387        Ukraine
# 714                    ýýýýýýýýýý ýýýýýýýýýýýý     1385   Saudi Arabia
# 752                      ýýýýýýýýýýýýýýýýýýýýý      364    South Korea
# 784  ýýýýýýýýýýýýýýýýýýýý ýýýýýýýýýýýýýýýýýýýý       65            NaN
# 795                               ýýýýýýýýýýýý     2210         Russia
# 810                   ýýýýýýýý ýý ýýýýýýýýýýýý      504  United States
# 866                         ýýýýýýýýýýýýýýýýýý      608         Russia
# 920               ýýýýýýýý ýýýý ýýýýýýýýýýýýýý     1255        Ukraine
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 64            RU      Education  ...                      300000.0
# 161           US  Entertainment  ...                      300000.0
# 433           US  Entertainment  ...                      100000.0
# 447           UA  Entertainment  ...                      100000.0
# 561           US  Entertainment  ...                      200000.0
# 606           RU          Games  ...                          10.0
# 632           SA           Film  ...                      300000.0
# 700           RU           News  ...                           NaN
# 707           UA          Howto  ...                           NaN
# 714           SA  Entertainment  ...                           NaN
# 752           KR  Entertainment  ...                      300000.0
# 784          NaN            NaN  ...                         132.0
# 795           RU          Games  ...                      200000.0
# 810           US         People  ...                      200000.0
# 866           RU  Entertainment  ...                      100000.0
# 920           UA  Entertainment  ...                      200000.0
#
#      created_year  created_month  created_date  \
# 64         2011.0            May          31.0
# 161        2018.0            Nov           3.0
# 433        2018.0            Feb          20.0
# 447        2014.0            Oct          20.0
# 561        2014.0            Mar           9.0
# 606        2017.0            May          27.0
# 632        2017.0            May          16.0
# 700        2008.0            Aug          11.0
# 707        2015.0            Oct          12.0
# 714        2016.0            May          27.0
# 752        2017.0            Mar           8.0
# 784        2017.0            Aug           4.0
# 795        2013.0            Oct          26.0
# 810        2018.0            Oct          12.0
# 866        2015.0            Oct           4.0
# 920        2014.0            Jul          17.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 64                                      81.9  144373535.0               4.59
# 161                                     88.2  328239523.0              14.70
# 433                                     88.2  328239523.0              14.70
# 447                                     82.7   44385155.0               8.88
# 561                                     88.2  328239523.0              14.70
# 606                                     81.9  144373535.0               4.59
# 632                                     68.0   34268528.0               5.93
# 700                                     81.9  144373535.0               4.59
# 707                                     82.7   44385155.0               8.88
# 714                                     68.0   34268528.0               5.93
# 752                                     94.3   51709098.0               4.15
# 784                                      NaN          NaN                NaN
# 795                                     81.9  144373535.0               4.59
# 810                                     88.2  328239523.0              14.70
# 866                                     81.9  144373535.0               4.59
# 920                                     82.7   44385155.0               8.88
#
#      Urban_population   Latitude   Longitude
# 64        107683889.0  61.524010  105.318756
# 161       270663028.0  37.090240  -95.712891
# 433       270663028.0  37.090240  -95.712891
# 447        30835699.0  48.379433   31.165580
# 561       270663028.0  37.090240  -95.712891
# 606       107683889.0  61.524010  105.318756
# 632        28807838.0  23.885942   45.079162
# 700       107683889.0  61.524010  105.318756
# 707        30835699.0  48.379433   31.165580
# 714        28807838.0  23.885942   45.079162
# 752        42106719.0  35.907757  127.766922
# 784               NaN        NaN         NaN
# 795       107683889.0  61.524010  105.318756
# 810       270663028.0  37.090240  -95.712891
# 866       107683889.0  61.524010  105.318756
# 920        30835699.0  48.379433   31.165580
#
# [16 rows x 28 columns]

# %%
# Remove rows from with blank Youtuber as these are channels with only special characters
df = df.drop(blanks_data_youtuber.index)
df.reset_index(drop= True, inplace= True)
df[df['Youtuber'] == '']
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %%
#Check zero data video views
zero_views = df[df['video views'] == 0]
zero_views
# Out:
#      rank            Youtuber  subscribers  video views          category  \
# 1       2      YouTube Movies    170000000          0.0  Film & Animation
# 5       6               Music    119000000          0.0               NaN
# 12     13              Gaming     93600000          0.0               NaN
# 18     19              Sports     75000000          0.0               NaN
# 101   103                News     36300000          0.0               NaN
# 171   174  Popular on YouTube     29300000          0.0               NaN
# 357   361   Minecraft - Topic     20900000          0.0               NaN
# 584   593                Live     16100000          0.0               NaN
#
#                   Title  uploads        Country Abbreviation   channel_type  \
# 1         youtubemovies        1  United States           US          Games
# 5                 Music        0            NaN          NaN          Music
# 12               Gaming        0            NaN          NaN          Games
# 18               sports        3  United States           US  Entertainment
# 101                News        0            NaN          NaN            NaN
# 171  Popular on Youtube        3            NaN          NaN      Education
# 357   Minecraft - Topic        0            NaN          NaN          Games
# 584                Live        0            NaN          NaN            NaN
#
#      ...  subscribers_for_last_30_days  created_year  created_month  \
# 1    ...                           NaN        2006.0            Mar
# 5    ...                           NaN        2013.0            Sep
# 12   ...                           NaN        2013.0            Dec
# 18   ...                           NaN        2006.0            Jan
# 101  ...                           NaN        2013.0            Sep
# 171  ...                           NaN        2017.0            Aug
# 357  ...                      300000.0        2013.0            Dec
# 584  ...                           NaN        2015.0            Jan
#
#      created_date  Gross tertiary education enrollment (%)   Population  \
# 1             5.0                                     88.2  328239523.0
# 5            24.0                                      NaN          NaN
# 12           15.0                                      NaN          NaN
# 18           30.0                                     88.2  328239523.0
# 101           9.0                                      NaN          NaN
# 171           7.0                                      NaN          NaN
# 357          20.0                                      NaN          NaN
# 584          13.0                                      NaN          NaN
#
#      Unemployment rate  Urban_population  Latitude  Longitude
# 1                 14.7       270663028.0  37.09024 -95.712891
# 5                  NaN               NaN       NaN        NaN
# 12                 NaN               NaN       NaN        NaN
# 18                14.7       270663028.0  37.09024 -95.712891
# 101                NaN               NaN       NaN        NaN
# 171                NaN               NaN       NaN        NaN
# 357                NaN               NaN       NaN        NaN
# 584                NaN               NaN       NaN        NaN
#
# [8 rows x 28 columns]

# %%
#Remove zero data video views
df = df.drop(zero_views.index)
df.reset_index(drop= True, inplace= True)
df[df['video views'] == 0]
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    37
# Title                                        0
# uploads                                      0
# Country                                    113
# Abbreviation                               113
# channel_type                                24
# video_views_rank                             0
# country_rank                               107
# channel_type_rank                           25
# video_views_for_the_last_30_days            45
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               322
# created_year                                 0
# created_month                                0
# created_date                                 0
# Gross tertiary education enrollment (%)    114
# Population                                 114
# Unemployment rate                          114
# Urban_population                           114
# Latitude                                   114
# Longitude                                  114
# dtype: int64

# %%
#Select category columns
categorical_variables = df.select_dtypes(include= 'O').columns

#Replace object datatype column missing values with 'Other'
df[categorical_variables] = df[categorical_variables].fillna('Other')

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                     0
# Title                                        0
# uploads                                      0
# Country                                      0
# Abbreviation                                 0
# channel_type                                 0
# video_views_rank                             0
# country_rank                               107
# channel_type_rank                           25
# video_views_for_the_last_30_days            45
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               322
# created_year                                 0
# created_month                                0
# created_date                                 0
# Gross tertiary education enrollment (%)    114
# Population                                 114
# Unemployment rate                          114
# Urban_population                           114
# Latitude                                   114
# Longitude                                  114
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     966 non-null    int64
#  1   Youtuber                                 966 non-null    object
#  2   subscribers                              966 non-null    int64
#  3   video views                              966 non-null    float64
#  4   category                                 966 non-null    object
#  5   Title                                    966 non-null    object
#  6   uploads                                  966 non-null    int64
#  7   Country                                  966 non-null    object
#  8   Abbreviation                             966 non-null    object
#  9   channel_type                             966 non-null    object
#  10  video_views_rank                         966 non-null    float64
#  11  country_rank                             859 non-null    float64
#  12  channel_type_rank                        941 non-null    float64
#  13  video_views_for_the_last_30_days         921 non-null    float64
#  14  lowest_monthly_earnings                  966 non-null    float64
#  15  highest_monthly_earnings                 966 non-null    float64
#  16  lowest_yearly_earnings                   966 non-null    float64
#  17  highest_yearly_earnings                  966 non-null    float64
#  18  subscribers_for_last_30_days             644 non-null    float64
#  19  created_year                             966 non-null    float64
#  20  created_month                            966 non-null    object
#  21  created_date                             966 non-null    float64
#  22  Gross tertiary education enrollment (%)  852 non-null    float64
#  23  Population                               852 non-null    float64
#  24  Unemployment rate                        852 non-null    float64
#  25  Urban_population                         852 non-null    float64
#  26  Latitude                                 852 non-null    float64
#  27  Longitude                                852 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 211.4+ KB

# %%
#Youtube is not null
youtube_not_null = df.dropna(subset= ['Gross tertiary education enrollment (%)','Unemployment rate', 'Population', 'Urban_population'])

#Mean Education Enrollment
mean_edu = round(youtube_not_null['Gross tertiary education enrollment (%)'].mean(),1)
print('Mean Gross Tertiary Education Enrollment:', mean_edu)

#Mean Unemployment Rate
mean_unemp = round(youtube_not_null['Unemployment rate'].mean(),1)
print('Mean Unemployment Rate:', mean_unemp)

#Mean Population
mean_popu = round(youtube_not_null['Population'].mean(),0)
print('Mean Population:', mean_popu)

#Mean Urban Population
mean_urban = round(youtube_not_null['Urban_population'].mean(),0)
print('Mean Urban Population:', mean_urban)
# Out:
# Mean Gross Tertiary Education Enrollment: 63.2
# Mean Unemployment Rate: 9.3
# Mean Population: 436369043.0
# Mean Urban Population: 226156206.0

# %%
#Replace object datatype column missing values with Mean Values
df['Gross tertiary education enrollment (%)'] = df['Gross tertiary education enrollment (%)'].fillna(mean_edu)
df['Unemployment rate'] = df['Unemployment rate'].fillna(mean_unemp)
df['Population'] = df['Population'].fillna(mean_popu)
df['Urban_population'] = df['Urban_population'].fillna(mean_urban)

# %%
# Convert several float data typescolumns to integars
df = df.astype({
    'video views': 'int64',
    'created_year': 'int64',
    'Population': 'int64',
    'Urban_population': 'int64'
})

# Validate results of datatype change
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     966 non-null    int64
#  1   Youtuber                                 966 non-null    object
#  2   subscribers                              966 non-null    int64
#  3   video views                              966 non-null    int64
#  4   category                                 966 non-null    object
#  5   Title                                    966 non-null    object
#  6   uploads                                  966 non-null    int64
#  7   Country                                  966 non-null    object
#  8   Abbreviation                             966 non-null    object
#  9   channel_type                             966 non-null    object
#  10  video_views_rank                         966 non-null    float64
#  11  country_rank                             859 non-null    float64
#  12  channel_type_rank                        941 non-null    float64
#  13  video_views_for_the_last_30_days         921 non-null    float64
#  14  lowest_monthly_earnings                  966 non-null    float64
#  15  highest_monthly_earnings                 966 non-null    float64
#  16  lowest_yearly_earnings                   966 non-null    float64
#  17  highest_yearly_earnings                  966 non-null    float64
#  18  subscribers_for_last_30_days             644 non-null    float64
#  19  created_year                             966 non-null    int64
#  20  created_month                            966 non-null    object
#  21  created_date                             966 non-null    float64
#  22  Gross tertiary education enrollment (%)  966 non-null    float64
#  23  Population                               966 non-null    int64
#  24  Unemployment rate                        966 non-null    float64
#  25  Urban_population                         966 non-null    int64
#  26  Latitude                                 852 non-null    float64
#  27  Longitude                                852 non-null    float64
# dtypes: float64(14), int64(7), object(7)
# memory usage: 211.4+ KB

# %%
#sorting the dataframe and resetting index (by 'Subscribers)
df = df.sort_values(by = 'subscribers', ascending= False).reset_index(drop= True)
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  228000000000
# 1       3                     MrBeast    166000000   28368841870
# 2       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 3       5                   SET India    159000000  148000000000
# 4       7             Kids Diana Show    112000000   93247040539
# ..    ...                         ...          ...           ...
# 961   991                 Natan por A     12300000    9029609749
# 962   992    Free Fire India Official     12300000    1674409945
# 963   993                       Panda     12300000    2214684303
# 964   994                 RobTopGames     12300000     374123483
# 965   995                Make Joke Of     12300000    2129773714
#
#            category                       Title  uploads         Country  \
# 0             Music                    T-Series    20082           India
# 1     Entertainment                     MrBeast      741   United States
# 2         Education  Cocomelon - Nursery Rhymes      966   United States
# 3             Shows                   SET India   116536           India
# 4    People & Blogs         ýýý Kids Diana Show     1111   United States
# ..              ...                         ...      ...             ...
# 961          Sports               Natan por Aï¿     1200          Brazil
# 962  People & Blogs    Free Fire India Official     1500           India
# 963           Other                 HybridPanda     2452  United Kingdom
# 964          Gaming                 RobTopGames       39          Sweden
# 965          Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US  Entertainment  ...                     8000000.0
# 2             US      Education  ...                     1000000.0
# 3             IN  Entertainment  ...                     1000000.0
# 4             US  Entertainment  ...                           NaN
# ..           ...            ...  ...                           ...
# 961           BR  Entertainment  ...                      700000.0
# 962           IN          Games  ...                      300000.0
# 963           GB          Games  ...                        1000.0
# 964           SE          Games  ...                      100000.0
# 965           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0            2006            Mar          13.0
# 1            2012            Feb          20.0
# 2            2006            Sep           1.0
# 3            2006            Sep          20.0
# 4            2015            May          12.0
# ..            ...            ...           ...
# 961          2017            Feb          12.0
# 962          2018            Sep          14.0
# 963          2006            Sep          11.0
# 964          2012            May           9.0
# 965          2017            Aug           1.0
#
#      Gross tertiary education enrollment (%)  Population  Unemployment rate  \
# 0                                       28.1  1366417754               5.36
# 1                                       88.2   328239523              14.70
# 2                                       88.2   328239523              14.70
# 3                                       28.1  1366417754               5.36
# 4                                       88.2   328239523              14.70
# ..                                       ...         ...                ...
# 961                                     51.3   212559417              12.08
# 962                                     28.1  1366417754               5.36
# 963                                     60.0    66834405               3.85
# 964                                     67.0    10285453               6.48
# 965                                     28.1  1366417754               5.36
#
#      Urban_population   Latitude  Longitude
# 0           471031528  20.593684  78.962880
# 1           270663028  37.090240 -95.712891
# 2           270663028  37.090240 -95.712891
# 3           471031528  20.593684  78.962880
# 4           270663028  37.090240 -95.712891
# ..                ...        ...        ...
# 961         183241641 -14.235004 -51.925280
# 962         471031528  20.593684  78.962880
# 963          55908316  55.378051  -3.435973
# 964           9021165  60.128161  18.643501
# 965         471031528  20.593684  78.962880
#
# [966 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     966 non-null    int64
#  1   Youtuber                                 966 non-null    object
#  2   subscribers                              966 non-null    int64
#  3   video views                              966 non-null    int64
#  4   category                                 966 non-null    object
#  5   Title                                    966 non-null    object
#  6   uploads                                  966 non-null    int64
#  7   Country                                  966 non-null    object
#  8   Abbreviation                             966 non-null    object
#  9   channel_type                             966 non-null    object
#  10  video_views_rank                         966 non-null    float64
#  11  country_rank                             859 non-null    float64
#  12  channel_type_rank                        941 non-null    float64
#  13  video_views_for_the_last_30_days         921 non-null    float64
#  14  lowest_monthly_earnings                  966 non-null    float64
#  15  highest_monthly_earnings                 966 non-null    float64
#  16  lowest_yearly_earnings                   966 non-null    float64
#  17  highest_yearly_earnings                  966 non-null    float64
#  18  subscribers_for_last_30_days             644 non-null    float64
#  19  created_year                             966 non-null    int64
#  20  created_month                            966 non-null    object
#  21  created_date                             966 non-null    float64
#  22  Gross tertiary education enrollment (%)  966 non-null    float64
#  23  Population                               966 non-null    int64
#  24  Unemployment rate                        966 non-null    float64
#  25  Urban_population                         966 non-null    int64
#  26  Latitude                                 852 non-null    float64
#  27  Longitude                                852 non-null    float64
# dtypes: float64(14), int64(7), object(7)
# memory usage: 211.4+ KB

# %%
# Rename specific columns
df = df.rename(columns={
    'Gross tertiary education enrollment (%)': 'gross education enrollment percentage',
    'Youtuber': 'youtuber',
    'Title': 'title',
    'Abbreviation': 'abbreviation',
    'Country' : 'country',
    'Population': 'population',
    'Unemployment rate': 'unemployment_rate',
    'Urban_population' : 'urban_population',
    'Latitude' : 'latitude',
    'Longitude' : 'longitude',
    'video views' : 'video_views'
    })

# Display the DataFrame with renamed columns
df.head()
# Out:
#    rank                    youtuber  subscribers   video_views  \
# 0     1                    T-Series    245000000  228000000000
# 1     3                     MrBeast    166000000   28368841870
# 2     4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 3     5                   SET India    159000000  148000000000
# 4     7             Kids Diana Show    112000000   93247040539
#
#          category                       title  uploads        country  \
# 0           Music                    T-Series    20082          India
# 1   Entertainment                     MrBeast      741  United States
# 2       Education  Cocomelon - Nursery Rhymes      966  United States
# 3           Shows                   SET India   116536          India
# 4  People & Blogs         ýýý Kids Diana Show     1111  United States
#
#   abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US  Entertainment  ...                     8000000.0
# 2           US      Education  ...                     1000000.0
# 3           IN  Entertainment  ...                     1000000.0
# 4           US  Entertainment  ...                           NaN
#
#    created_year  created_month  created_date  \
# 0          2006            Mar          13.0
# 1          2012            Feb          20.0
# 2          2006            Sep           1.0
# 3          2006            Sep          20.0
# 4          2015            May          12.0
#
#    gross education enrollment percentage  population  unemployment_rate  \
# 0                                   28.1  1366417754               5.36
# 1                                   88.2   328239523              14.70
# 2                                   88.2   328239523              14.70
# 3                                   28.1  1366417754               5.36
# 4                                   88.2   328239523              14.70
#
#    urban_population   latitude  longitude
# 0         471031528  20.593684  78.962880
# 1         270663028  37.090240 -95.712891
# 2         270663028  37.090240 -95.712891
# 3         471031528  20.593684  78.962880
# 4         270663028  37.090240 -95.712891
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   rank                                   966 non-null    int64
#  1   youtuber                               966 non-null    object
#  2   subscribers                            966 non-null    int64
#  3   video_views                            966 non-null    int64
#  4   category                               966 non-null    object
#  5   title                                  966 non-null    object
#  6   uploads                                966 non-null    int64
#  7   country                                966 non-null    object
#  8   abbreviation                           966 non-null    object
#  9   channel_type                           966 non-null    object
#  10  video_views_rank                       966 non-null    float64
#  11  country_rank                           859 non-null    float64
#  12  channel_type_rank                      941 non-null    float64
#  13  video_views_for_the_last_30_days       921 non-null    float64
#  14  lowest_monthly_earnings                966 non-null    float64
#  15  highest_monthly_earnings               966 non-null    float64
#  16  lowest_yearly_earnings                 966 non-null    float64
#  17  highest_yearly_earnings                966 non-null    float64
#  18  subscribers_for_last_30_days           644 non-null    float64
#  19  created_year                           966 non-null    int64
#  20  created_month                          966 non-null    object
#  21  created_date                           966 non-null    float64
#  22  gross education enrollment percentage  966 non-null    float64
#  23  population                             966 non-null    int64
#  24  unemployment_rate                      966 non-null    float64
#  25  urban_population                       966 non-null    int64
#  26  latitude                               852 non-null    float64
#  27  longitude                              852 non-null    float64
# dtypes: float64(14), int64(7), object(7)
# memory usage: 211.4+ KB

# %%
df.to_csv('./Resources/database.csv', index=False)

# %%
file_path = './Resources/database.csv'  # Replace with the path to your CSV filed
df= pd.read_csv(file_path)

# %%
#create engine to sqlite file
engine = create_engine("sqlite:///Resources/Youtubedata.sqlite", echo=False)

# %%
df.to_sql("my_table", con=engine, if_exists='replace', index=False)
# Out:
# 966

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

# %%
# Create a session
session = Session(engine)

# %%
#utilize inspector to confirm existance 
# INSPECT to confirm existence

# Create the inspector and connect it to the engine
inspector_gadget = inspect(engine)

# Collect the names of tables within the database
tables = inspector_gadget.get_table_names()

# print metadata for each table
for table in tables:
    print(table)
    print("-----------")
    
    # get columns
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# my_table
# -----------
# rank BIGINT
# youtuber TEXT
# subscribers BIGINT
# video_views BIGINT
# category TEXT
# title TEXT
# uploads BIGINT
# country TEXT
# abbreviation TEXT
# channel_type TEXT
# video_views_rank FLOAT
# country_rank FLOAT
# channel_type_rank FLOAT
# video_views_for_the_last_30_days FLOAT
# lowest_monthly_earnings FLOAT
# highest_monthly_earnings FLOAT
# lowest_yearly_earnings FLOAT
# highest_yearly_earnings FLOAT
# subscribers_for_last_30_days FLOAT
# created_year BIGINT
# created_month TEXT
# created_date FLOAT
# gross education enrollment percentage FLOAT
# population BIGINT
# unemployment_rate FLOAT
# urban_population BIGINT
# latitude FLOAT
# longitude FLOAT

# %%
#1. Define the SQL query top channels by subscribers
query = """
SELECT Rank, Youtuber, subscribers / 1000000 AS "subscribers (million)", country, channel_type
FROM my_table
ORDER BY subscribers DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                     youtuber  subscribers (million)  \
# 0      1                                     T-Series                    245
# 1      3                                      MrBeast                    166
# 2      4                   Cocomelon - Nursery Rhymes                    162
# 3      5                                    SET India                    159
# 4      7                              Kids Diana Show                    112
# 5      8                                    PewDiePie                    111
# 6      9                                  Like Nastya                    106
# 7     10                                Vlad and Niki                     98
# 8     11                            Zee Music Company                     96
# 9     12                                          WWE                     96
# 10    14                                    BLACKPINK                     89
# 11    15                                    Goldmines                     86
# 12    16                                     Sony SAB                     83
# 13    17                              5-Minute Crafts                     80
# 14    18                                    BANGTANTV                     75
# 15    20                                Justin Bieber                     71
# 16    21                                  HYBE LABELS                     71
# 17    22                                       Zee TV                     70
# 18    23  Pinkfong Baby Shark - Kids' Songs & Stories                     68
# 19    24                              Canal KondZilla                     66
# 20    25        ChuChu TV Nursery Rhymes & Kids Songs                     65
# 21    26                         Shemaroo Filmi Gaane                     65
# 22    27                                    Colors TV                     64
# 23    28                        T-Series Bhakti Sagar                     61
# 24    29                                 Dude Perfect                     59
#
#            country   channel_type
# 0            India          Music
# 1    United States  Entertainment
# 2    United States      Education
# 3            India  Entertainment
# 4    United States  Entertainment
# 5            Japan  Entertainment
# 6           Russia         People
# 7    United States  Entertainment
# 8            India          Music
# 9    United States         Sports
# 10     South Korea          Music
# 11           Other          Music
# 12           India  Entertainment
# 13  United Kingdom  Entertainment
# 14     South Korea          Music
# 15          Canada          Music
# 16     South Korea          Music
# 17           India  Entertainment
# 18   United States      Education
# 19          Brazil          Music
# 20           India      Education
# 21           India          Music
# 22           India  Entertainment
# 23           India          Music
# 24   United States         Sports

# %%
#2. What are the top 25 YouTube channels by country?
query = """
SELECT Rank, Youtuber, subscribers /1000000 AS "subscribers (million)", country, channel_type, category
FROM my_table
GROUP BY country 
ORDER BY channel_type DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                    youtuber  subscribers (million)  \
# 0    424                        FIFA                     19
# 1     77                     shfa2 -                     39
# 2      9                 Like Nastya                    106
# 3     72             Kimberly Loaiza                     41
# 4     51                          A4                     46
# 5    664                       Musas                     15
# 6    191          Sandeep Maheshwari                     27
# 7    372                      Avicii                     20
# 8     14                   BLACKPINK                     89
# 9    900                   DJ Khaled                     13
# 10    15                   Goldmines                     86
# 11   168            Spinnin' Records                     30
# 12   750              Saad Lamjarred                     14
# 13   166              toyoraljanahtv                     30
# 14   518                    Al-Remas                     17
# 15     1                    T-Series                    245
# 16   316                Smile Family                     22
# 17    20               Justin Bieber                     71
# 18    24             Canal KondZilla                     66
# 19    70                     Rihanna                     41
# 20   192  Bounce Patrol - Kids Songs                     27
# 21    32           El Reino Infantil                     58
# 22   638                           5                     15
# 23    64                     Shakira                     43
# 24   508                      Liziqi                     17
#
#                  country channel_type          category
# 0            Switzerland       Sports            Sports
# 1   United Arab Emirates       People    People & Blogs
# 2                 Russia       People    People & Blogs
# 3                 Mexico       People    People & Blogs
# 4                   Cuba       People            Gaming
# 5                Andorra       People     Howto & Style
# 6              Singapore        Other    People & Blogs
# 7                 Sweden        Music             Music
# 8            South Korea        Music    People & Blogs
# 9                  Samoa        Music             Music
# 10                 Other        Music  Film & Animation
# 11           Netherlands        Music             Music
# 12               Morocco        Music             Music
# 13                Jordan        Music     Entertainment
# 14                  Iraq        Music             Music
# 15                 India        Music             Music
# 16                France        Music    People & Blogs
# 17                Canada        Music             Music
# 18                Brazil        Music             Music
# 19              Barbados        Music     Entertainment
# 20             Australia        Music             Music
# 21             Argentina        Music             Music
# 22                 Egypt        Howto     Howto & Style
# 23              Colombia        Howto    People & Blogs
# 24                 China        Howto     Howto & Style

# %%
#3. What are the top 25 YouTube channels by the number of views?
query = """
SELECT Rank, Youtuber, subscribers/1000000 AS "subscribers (million)", video_views/1000000 AS "video_views (million)", country, channel_type
FROM my_table
GROUP BY channel_type
ORDER BY video_views DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                           youtuber  \
# 0      1                                           T-Series
# 1      4                         Cocomelon - Nursery Rhymes
# 2      9                                        Like Nastya
# 3     12                                                WWE
# 4     30                                         Movieclips
# 5     39  LooLoo Kids - Nursery Rhymes and Children's Songs
# 6      3                                            MrBeast
# 7     64                                            Shakira
# 8     34                                            Aaj Tak
# 9    276                                   That Little Puff
# 10    45                                        JuegaGerman
# 11    85                                         TEDx Talks
# 12   144                                  MR. INDIAN HACKER
# 13   110                                       Total Gaming
# 14    60                                   whinderssonnunes
#
#     subscribers (million)  video_views (million)        country   channel_type
# 0                     245                 228000          India          Music
# 1                     162                 164000  United States      Education
# 2                     106                  90479         Russia         People
# 3                      96                  77428  United States         Sports
# 4                      59                  59316  United States           Film
# 5                      54                  32312          Other          Other
# 6                     166                  28368  United States  Entertainment
# 7                      43                  27568       Colombia          Howto
# 8                      57                  25307          India           News
# 9                      23                  20289  United States        Animals
# 10                     48                  14631          Chile          Games
# 11                     38                   7339  United States      Nonprofit
# 12                     31                   5711          India           Tech
# 13                     35                   5556          Other          Autos
# 14                     44                   4274         Brazil         Comedy

# %%
#4. What categories will get the most views ?
query = """
SELECT rank, youtuber, subscribers /1000000 AS subscribers_million, channel_type, category, country, SUM(video_views) AS total_views
FROM my_table
GROUP BY category
ORDER BY video_views DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                    youtuber  subscribers_million   channel_type  \
# 0      1                    T-Series                  245          Music
# 1      4  Cocomelon - Nursery Rhymes                  162      Education
# 2      5                   SET India                  159  Entertainment
# 3      7             Kids Diana Show                  112  Entertainment
# 4     12                         WWE                   96         Sports
# 5      8                   PewDiePie                  111  Entertainment
# 6      3                     MrBeast                  166  Entertainment
# 7     17             5-Minute Crafts                   80  Entertainment
# 8     34                     Aaj Tak                   57           News
# 9     15                   Goldmines                   86          Music
# 10    92                      Vlad v                   37  Entertainment
# 11   276            That Little Puff                   23        Animals
# 12    71                Ishtar Music                   41          Music
# 13   183               Aditya Movies                   28           Film
# 14   334                DUDU e CAROL                   21  Entertainment
# 15    85                  TEDx Talks                   38      Nonprofit
# 16   144           MR. INDIAN HACKER                   31           Tech
# 17    60            whinderssonnunes                   44         Comedy
# 18   957                           M                   12  Entertainment
#
#                  category         country    total_views
# 0                   Music           India  3103516219048
# 1               Education   United States   691690418531
# 2                   Shows           India   432356612140
# 3          People & Blogs   United States  1251773521276
# 4                  Sports   United States   147986290620
# 5                  Gaming           Japan   706166809255
# 6           Entertainment   United States  2500154780534
# 7           Howto & Style  United Kingdom   194799530478
# 8         News & Politics           India   270391919347
# 9        Film & Animation           Other   507963782337
# 10                  Other   United States   278191674947
# 11         Pets & Animals   United States    44866745899
# 12               Trailers           India    33262717607
# 13                 Movies           India    15383255129
# 14       Autos & Vehicles          Brazil    15003458141
# 15  Nonprofits & Activism   United States    10862911785
# 16   Science & Technology           India    66976747110
# 17                 Comedy          Brazil   550112774315
# 18        Travel & Events          Mexico     3140883140

# %%
# Create the bar chart with the 'Reds' color scale for red tones
fig = px.bar(df.head(10), x='subscribers_million', y='youtuber', orientation='h', text='subscribers_million',
             color='subscribers_million', labels={'subscribers_million': 'Subscribers (in millions)'},
             color_continuous_scale='Reds')  # Use the 'Reds' color scale for red tones

# Customize the appearance of the bar chart
fig.update_traces(marker_line_color='rgb(7,40,47)', marker_line_width=1.5, opacity=0.8, textposition='inside')
fig.update_layout(title_text='Top 10 YouTube Channels by Subscribers', yaxis_title='YouTube Channel',
                  xaxis_title='Subscribers (in millions)', height=500)

fig.show()
# Out:
# <div>                            <div id="d1363e8b-f55c-4528-9a57-2740eb3e8335" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1363e8b-f55c-4528-9a57-2740eb3e8335")) {                    Plotly.newPlot(                        "d1363e8b-f55c-4528-9a57-2740eb3e8335",                        [{"alignmentgroup":"True","hovertemplate":"Subscribers (in millions)=%{marker.color}<br>youtuber=%{y}<extra></extra>","legendgroup":"","marker":{"color":[245,162,159,112,96,111,166,80,57,86],"coloraxis":"coloraxis","pattern":{"shape":""},"line":{"color":"rgb(7,40,47)","width":1.5}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[245.0,162.0,159.0,112.0,96.0,111.0,166.0,80.0,57.0,86.0],"textposition":"inside","x":[245,162,159,112,96,111,166,80,57,86],"xaxis":"x","y":["T-Series","Cocomelon - Nursery Rhymes","SET India","Kids Diana Show","WWE","PewDiePie","MrBeast","5-Minute Crafts","Aaj Tak","Goldmines"],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[ ...

# %%
# Define a custom color palette without white for YouTube branding
youtube_colors_no_white = ['#FF0000', '#282828', '#FF3333']  # Red, Dark Gray, Light Red

# Create the sunburst chart with custom colors (without white) for YouTube branding
fig = px.sunburst(df, path=['channel_type'], color_discrete_sequence=youtube_colors_no_white)
fig.update_layout(title_text='Distribution of YouTube Channel Types', height=500)
fig.show()
# Out:
# <div>                            <div id="88caa673-3b91-4b15-aa4d-972d71904cb1" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88caa673-3b91-4b15-aa4d-972d71904cb1")) {                    Plotly.newPlot(                        "88caa673-3b91-4b15-aa4d-972d71904cb1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Animals","Comedy","Education","Entertainment","Film","Music","News","Nonprofit","Sports","Tech"],"labels":["Animals","Comedy","Education","Entertainment","Film","Music","News","Nonprofit","Sports","Tech"],"name":"","parents":["","","","","","","","","",""],"values":[1,1,1,8,1,3,1,1,1,1],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo" ...

# %%
# 5. Which channels have the highest total video views?
query = """
SELECT category, channel_type, SUM(video_views)/1000000 AS "total_views" 
FROM my_table
GROUP BY channel_type
ORDER BY total_views DESC
LIMIT 25 """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                  category   channel_type  total_views
# 0           Entertainment  Entertainment      3322035
# 1                   Music          Music      3250295
# 2          People & Blogs         People       877467
# 3               Education      Education       728347
# 4                  Gaming          Games       711352
# 5                  Comedy         Comedy       453140
# 6        Film & Animation           Film       450977
# 7         News & Politics           News       311352
# 8                   Music          Other       215963
# 9          People & Blogs          Howto       188632
# 10                 Sports         Sports       181104
# 11   Science & Technology           Tech        59355
# 12         Pets & Animals        Animals        44135
# 13                 Gaming          Autos        19577
# 14  Nonprofits & Activism      Nonprofit        10862

# %%
# 6. What are the top 25 Youtube channels by upload
query = """
SELECT rank, youtuber, channel_type, uploads 
FROM my_table
ORDER BY uploads DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank               youtuber   channel_type  uploads
# 0     96               ABP NEWS           News   301308
# 1    858    GMA Integrated News           News   296272
# 2    748        TV9 Bharatvarsh           News   293516
# 3     34                Aaj Tak           News   283775
# 4    108                IndiaTV           News   273255
# 5    690               KOMPASTV           News   269050
# 6    587        Thairath Online           News   244899
# 7    503                News 24           News   211620
# 8    674           ABS-CBN News           News   209520
# 9     85             TEDx Talks      Nonprofit   200933
# 10    61  ABS-CBN Entertainment  Entertainment   193890
# 11   819               Geo News           News   190093
# 12   513           News18 India           News   182742
# 13   158               Zee News           News   180092
# 14   918              AlArabiya           News   169304
# 15   659                    CNN           News   160405
# 16   515                    IGN          Games   156215
# 17   961                   NDTV           News   151136
# 18   531      TRANS TV Official  Entertainment   148225
# 19   781             Zee Bangla  Entertainment   132398
# 20    22                 Zee TV  Entertainment   129204
# 21   423         etvteluguindia  Entertainment   125974
# 22   517               AMARINTV           News   118448
# 23    94                  one31  Entertainment   117152
# 24     5              SET India  Entertainment   116536

# %%
# 7. Channels with the highest yearly earnings
query = """
SELECT rank, youtuber, subscribers /1000000 AS "subscribers (million)", category, country,  MAX(highest_yearly_earnings) AS highest_yearly_earnings
FROM my_table
GROUP BY youtuber
ORDER BY highest_yearly_earnings DESC
LIMIT 50;
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(50)
# Out:
#     rank                     youtuber  subscribers (million)  \
# 0    496                       KIMPRO                     17
# 1    418                 DaFuq!?Boom!                     19
# 2      1                     T-Series                    245
# 3    303          KL BRO Biju Rithvik                     22
# 4      4   Cocomelon - Nursery Rhymes                    162
# 5      5                    SET India                    159
# 6     22                       Zee TV                     70
# 7    140                     StarPlus                     32
# 8     16                     Sony SAB                     83
# 9     84                  GR6 EXPLODE                     38
# 10   333   ZAMZAM ELECTRONICS TRADING                     21
# 11   133                      BETER B                     32
# 12   484                  BeatboxJCOP                     18
# 13   799                     ViralHog                     14
# 14     3                      MrBeast                    166
# 15    57                  HAR PAL GEO                     44
# 16   389                    dednahype                     20
# 17   213                    PANDA BOI                     26
# 18   713                   Filaretiki                     14
# 19    27                    Colors TV                     64
# 20   311               LeoNata Family                     22
# 21    66               ARY Digital HD                     43
# 22   906                         GH'S                     13
# 23   212             Alan Chikin Chow                     26
# 24   306                       Sun TV                     22
# 25   379             Vijay Television                     20
# 26   971                       vector                     12
# 27   365                      Yoeslan                     20
# 28    41            Infobells - Hindi                     53
# 29   232                     LankyBox                     25
# 30    87  Goldmines Gaane Sune Ansune                     38
# 31    11            Zee Music Company                     96
# 32   142                 GMA  Network                     31
# 33   264                 Spider Slack                     24
# 34   295                 Tsuriki Show                     23
# 35   276             That Little Puff                     23
# 36     7              Kids Diana Show                    112
# 37   345                Ishaan Ali 11                     21
# 38   216                       Junya.                     26
# 39    12                          WWE                     96
# 40   675                  Chapitosiki                     15
# 41   321                       Sagawa                     22
# 42   324                 Topper Guild                     21
# 43   186                       HUM TV                     28
# 44    68           Masha and The Bear                     42
# 45   505          El Payaso Plim Plim                     17
# 46   560                 Younes Zarou                     16
# 47    32            El Reino Infantil                     58
# 48   219                     NichLmao                     26
# 49    21                  HYBE LABELS                     71
#
#             category               country  highest_yearly_earnings
# 0              Other           South Korea              163400000.0
# 1   Film & Animation         United States              110600000.0
# 2              Music                 India              108400000.0
# 3      Entertainment                 Other               97600000.0
# 4          Education         United States               94800000.0
# 5              Shows                 India               87500000.0
# 6      Entertainment                 India               81900000.0
# 7      Entertainment                 India               80000000.0
# 8              Shows                 India               79600000.0
# 9              Music                Brazil               78500000.0
# 10             Other  United Arab Emirates               76700000.0
# 11             Other                Turkey               70200000.0
# 12  Film & Animation                 Other               66000000.0
# 13    People & Blogs         United States               65500000.0
# 14     Entertainment         United States               64700000.0
# 15     Entertainment              Pakistan               64200000.0
# 16            Comedy                Latvia               59800000.0
# 17     Entertainment                 Italy               58800000.0
# 18             Other         United States               57800000.0
# 19             Shows                 India               57000000.0
# 20    People & Blogs         United States               56300000.0
# 21     Entertainment              Pakistan               55200000.0
# 22            Gaming           South Korea               51900000.0
# 23            Comedy         United States               50200000.0
# 24    People & Blogs                 India               47100000.0
# 25     Entertainment                 India               43600000.0
# 26            Comedy         United States               43400000.0
# 27     Entertainment         United States               42000000.0
# 28         Education                 India               39200000.0
# 29            Comedy         United States               39100000.0
# 30             Music                 India               39100000.0
# 31             Music                 India               38600000.0
# 32     Entertainment           Philippines               38300000.0
# 33            Comedy                Brazil               36500000.0
# 34     Entertainment               Germany               36300000.0
# 35    Pets & Animals         United States               36200000.0
# 36    People & Blogs         United States               35100000.0
# 37    People & Blogs                 India               35000000.0
# 38     Entertainment                 Japan               34600000.0
# 39            Sports         United States               34300000.0
# 40     Entertainment                Russia               34200000.0
# 41     Entertainment                 Japan               34100000.0
# 42            Comedy         United States               33000000.0
# 43     Entertainment              Pakistan               32900000.0
# 44             Shows         United States               32200000.0
# 45  Film & Animation             Argentina               30700000.0
# 46     Entertainment               Germany               29600000.0
# 47             Music             Argentina               29400000.0
# 48    People & Blogs                 Other               29100000.0
# 49             Music           South Korea               28700000.0

# %%
# 8. Calculate the average earnings per YouTuber:
query = """ 
SELECT 
    Youtuber,
    country,
    AVG((lowest_monthly_earnings + highest_monthly_earnings) / 2) AS avg_monthly_earnings,
    AVG((lowest_yearly_earnings + highest_yearly_earnings) / 2) AS avg_yearly_earnings
FROM my_table
WHERE rank <= 25
GROUP BY Youtuber, country
ORDER BY avg_yearly_earnings DESC;
"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                                        youtuber         country  \
# 0                                      T-Series           India
# 1                    Cocomelon - Nursery Rhymes   United States
# 2                                     SET India           India
# 3                                        Zee TV           India
# 4                                      Sony SAB           India
# 5                                       MrBeast   United States
# 6                             Zee Music Company           India
# 7                               Kids Diana Show   United States
# 8                                           WWE   United States
# 9                                   HYBE LABELS     South Korea
# 10                                Vlad and Niki   United States
# 11                                    BLACKPINK     South Korea
# 12  Pinkfong Baby Shark - Kids' Songs & Stories   United States
# 13        ChuChu TV Nursery Rhymes & Kids Songs           India
# 14                                Justin Bieber          Canada
# 15                                    BANGTANTV     South Korea
# 16                                  Like Nastya          Russia
# 17                                    PewDiePie           Japan
# 18                                    Goldmines           Other
# 19                              5-Minute Crafts  United Kingdom
# 20                              Canal KondZilla          Brazil
#
#     avg_monthly_earnings  avg_yearly_earnings
# 0            4782300.000         5.760000e+07
# 1            4196900.000         5.035000e+07
# 2            3877950.000         4.650000e+07
# 3            3613400.000         4.350000e+07
# 4            3507150.000         4.230000e+07
# 5            2868500.000         3.435000e+07
# 6            1700450.000         2.050000e+07
# 7            1541450.000         1.865000e+07
# 8            1539350.000         1.820000e+07
# 9            1274750.000         1.525000e+07
# 10           1222550.000         1.480000e+07
# 11           1062350.000         1.270000e+07
# 12           1009150.000         1.205000e+07
# 13            902550.000         1.075000e+07
# 14            374700.000         4.514500e+06
# 15            357650.000         4.302450e+06
# 16            104000.000         1.223400e+06
# 17             83250.000         1.008800e+06
# 18                 0.035         4.550000e-01
# 19                 0.000         2.500000e-02
# 20                 0.000         0.000000e+00

# %%
# 9. Calculate the average earnings per country:
query = """ 
SELECT 
    country,
    AVG((lowest_monthly_earnings + highest_monthly_earnings) / 2) AS avg_monthly_earnings,
    AVG((lowest_yearly_earnings + highest_yearly_earnings) / 2) AS avg_yearly_earnings
FROM my_table
WHERE rank <= 25
GROUP BY country
ORDER BY avg_yearly_earnings DESC;
"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#           country  avg_monthly_earnings  avg_yearly_earnings
# 0           India          3.063967e+06         3.685833e+07
# 1   United States          2.062983e+06         2.473333e+07
# 2     South Korea          8.982500e+05         1.075082e+07
# 3          Canada          3.747000e+05         4.514500e+06
# 4          Russia          1.040000e+05         1.223400e+06
# 5           Japan          8.325000e+04         1.008800e+06
# 6           Other          3.500000e-02         4.550000e-01
# 7  United Kingdom          0.000000e+00         2.500000e-02
# 8          Brazil          0.000000e+00         0.000000e+00

# %%
# 10. Category with the most channels in the top 100 by subscribers:
query = """ 
SELECT rank, category, subscribers, COUNT(*) AS Channel_Count
FROM my_table
WHERE rank <= 100
GROUP BY category
ORDER BY Channel_Count DESC
LIMIT 10
"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#    rank          category  subscribers  Channel_Count
# 0     1             Music    245000000             30
# 1     3     Entertainment    166000000             20
# 2     7    People & Blogs    112000000             11
# 3     4         Education    162000000              7
# 4     8            Gaming    111000000              6
# 5     5             Shows    159000000              5
# 6    60            Comedy     44200000              4
# 7    15  Film & Animation     86900000              3
# 8    71          Trailers     41400000              2
# 9    12            Sports     96000000              2

# %%
# 11. How do YouTube channels from different countries compare in terms of average subscribers and views?
query = """ 
SELECT rank, country, 
       AVG(subscribers)/1000000 AS avg_subscribers,
       AVG(video_views)/1000000 AS avg_video_views
FROM my_table
GROUP BY Country
ORDER BY avg_subscribers DESC, avg_video_views DESC """
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank               country  avg_subscribers  avg_video_views
# 0     51                  Cuba        46.300000     22936.630813
# 1     53           El Salvador        46.100000     10323.391593
# 2     70              Barbados        41.900000     22477.745835
# 3      8                 Japan        37.820000     17136.403487
# 4    152             Venezuela        31.200000      9673.649438
# 5    159                Kuwait        30.500000      4521.573939
# 6     14           South Korea        29.206250     14061.970697
# 7     45                 Chile        29.066667      9782.518859
# 8      9                Russia        27.809091     16408.127511
# 9     57              Pakistan        25.900000     18882.236237
# 10     1                 India        25.658333     13577.668900
# 11    32             Argentina        25.269231     14955.027227
# 12    20                Canada        24.260000     12754.704939
# 13    64              Colombia        24.045455     14017.982514
# 14   133                Turkey        22.900000     23099.811190
# 15     3         United States        22.844118     11930.672835
# 16    15                 Other        22.561062     10238.172792
# 17   166                Jordan        22.333333     17696.693295
# 18    62              Thailand        21.472222     14684.331930
# 19    17        United Kingdom        21.334884     10013.175154
# 20    86          Saudi Arabia        21.271429      9881.552691
# 21    77  United Arab Emirates        21.171429     10760.087629
# 22   378           Afghanistan        20.400000     13397.000296
# 23   389                Latvia        20.200000     20919.403720
# 24    61           Philippines        20.008333     10760.670324

# %%
# 11. Channel type location latitude and longitude

# user inputs
user_country = 'All'



# switch on user_country
if user_country == 'All':
    where_clause = "and 1=1"
else:
    where_clause = f"and country = '{user_country}'"

query = f""" 
SELECT 
    country,
    latitude, 
    longitude, 
    COUNT(channel_type) AS channel_count
FROM 
    my_table
     
GROUP BY 
    Latitude, 
    Longitude
ORDER BY 
    channel_count DESC
    """

# Execute the query and read the results into a DataFrame
map_df = pd.read_sql(text(query), con=engine)
map_df.head(25)
# Out:
#                  country   latitude   longitude  channel_count
# 0          United States  37.090240  -95.712891            306
# 1                  India  20.593684   78.962880            168
# 2                  Other        NaN         NaN            114
# 3                 Brazil -14.235004  -51.925280             61
# 4         United Kingdom  55.378051   -3.435973             43
# 5                 Mexico  23.634501 -102.552784             33
# 6              Indonesia  -0.789275  113.921327             28
# 7                  Spain  40.463667   -3.749220             22
# 8               Thailand  15.870032  100.992541             18
# 9            South Korea  35.907757  127.766922             16
# 10                Canada  56.130366 -106.346771             15
# 11             Argentina -38.416097  -63.616672             13
# 12           Philippines  12.879721  121.774017             12
# 13              Colombia   4.570868  -74.297333             11
# 14                Russia  61.524010  105.318756             11
# 15             Australia -25.274398  133.775136              8
# 16  United Arab Emirates  23.424076   53.847818              7
# 17          Saudi Arabia  23.885942   45.079162              7
# 18              Pakistan  30.375321   69.345116              6
# 19               Germany  51.165691   10.451526              6
# 20                 Japan  36.204824  138.252924              5
# 21                France  46.227638    2.213749              5
# 22               Ukraine  48.379433   31.165580              5
# 23                Turkey  38.963745   35.243322              4
# 24                Sweden  60.128161   18.643501              4

# %%
# 12. Compare country youtuber's performace base on Population, Unemployment rate, Urban_population 
query = """
SELECT 
    country,
    population, 
    unemployment_rate, 
    urban_population, 
    COUNT(channel_type) AS channel_count
FROM 
    my_table
GROUP BY 
    country
ORDER BY 
    channel_count DESC
    """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                  country  population  unemployment_rate  urban_population  \
# 0          United States   328239523              14.70         270663028
# 1                  India  1366417754               5.36         471031528
# 2                  Other   436369043               9.30         226156206
# 3                 Brazil   212559417              12.08         183241641
# 4         United Kingdom    66834405               3.85          55908316
# 5                 Mexico   126014024               3.42         102626859
# 6              Indonesia   270203917               4.69         151509724
# 7                  Spain    47076781              13.96          37927409
# 8               Thailand    69625582               0.75          35294600
# 9            South Korea    51709098               4.15          42106719
# 10                Canada    36991981               5.56          30628482
# 11             Argentina    44938712               9.79          41339571
# 12           Philippines   108116615               2.15          50975903
# 13                Russia   144373535               4.59         107683889
# 14              Colombia    50339443               9.71          40827302
# 15             Australia    25766605               5.27          21844756
# 16  United Arab Emirates     9770529               2.35           8479744
# 17          Saudi Arabia    34268528               5.93          28807838
# 18              Pakistan   216565318               4.45          79927762
# 19               Germany    83132799               3.04          64324835
# 20               Ukraine    44385155               8.88          30835699
# 21                 Japan   126226568               2.29         115782416
# 22                France    67059887               8.43          54123364
# 23                Turkey    83429615              13.49          63097818
# 24                Sweden    10285453               6.48           9021165
#
#     channel_count
# 0             306
# 1             168
# 2             113
# 3              61
# 4              43
# 5              33
# 6              28
# 7              22
# 8              18
# 9              16
# 10             15
# 11             13
# 12             12
# 13             11
# 14             11
# 15              8
# 16              7
# 17              7
# 18              6
# 19              6
# 20              5
# 21              5
# 22              5
# 23              4
# 24              4

# %%
query = """
SELECT 
    CASE 
        WHEN Country IN ('Algeria','Angola','Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon','Central African Republic',
            'Chad','Comoros','Congo, Dem. Rep', 'Congo, Rep.','Cote d''Ivoire','Djibouti','Egypt','Equatorial Guinea','Eritrea',
            'Eswatini (formerly Swaziland)','Ethiopia','Gabon','Gambia','Ghana','Guinea','Guinea-Bissau','Kenya', 'Lesotho',
            'Liberia','Libya','Madagascar','Malawi','Mali','Mauritania','Mauritius','Morocco','Mozambique','Namibia',
            'Niger','Nigeria','Rwanda','Sao Tome and Principe','Senegal','Seychelles','Sierra Leone','Somalia','South Africa',
            'South Sudan','Sudan','Tanzania','Togo','Tunisia','Uganda','Zambia','Zimbabwe') THEN 'Africa'
        
        WHEN Country IN ('Albania','Andorra', 'Armenia','Austria','Azerbaijan','Belarus','Belgium','Bosnia and Herzegovina',
            'Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Georgia','Germany',
            'Greece','Hungary','Iceland','Ireland','Italy','Kazakhstan','Kosovo','Latvia','Liechtenstein','Lithuania',
            'Luxembourg','Malta','Moldova','Monaco','Montenegro','Netherlands','Macedonia, FYR','Norway','Poland','Portugal',
            'Romania','Russia','San Marino','Serbia','Slovakia','Slovenia','Spain','Sweden','Switzerland','Turkey',
            'Ukraine','United Kingdom','Vatican City') THEN 'Europe'
        
        WHEN Country IN ('Afghanistan','Armenia','Azerbaijan','Bahrain','Bangladesh', 'Bhutan','Brunei','Cambodia','China','Cyprus',
            'Georgia','India','Indonesia','Iran','Iraq','Israel','Japan','Jordan','Kazakhstan','Kuwait','Kyrgyzstan','Laos',
            'Lebanon','Malaysia','Maldives','Mongolia','Myanmar','Nepal','North Korea','Oman','Pakistan','Palestine','Philippines',
            'Qatar','Russia','Saudi Arabia','Singapore','South Korea','Sri Lanka','Syria','Taiwan','Tajikistan','Thailand',
            'Timor-Leste','Turkey','Turkmenistan','United Arab Emirates','Uzbekistan','Vietnam','Yemen') THEN 'Asia'
        
        WHEN Country IN ('Antigua and Barbuda','Bahamas','Barbados','Belize','Canada','Costa Rica','Cuba','Dominica',
            'Dominican Republic','El Salvador','Grenada','Guatemala','Haiti','Honduras','Jamaica','Mexico',
            'Nicaragua','Panama','Saint Vincent and the Grenadines','United States') THEN 'North_America'
        
        WHEN Country IN ('Argentina','Bolivia','Brazil','Chile','Colombia','Ecuador','Guyana','Paraguay','Peru','Suriname',
            'Uruguay','Venezuela') THEN 'South_America'
        
        WHEN Country IN ('Australia','Fiji','Kiribati','Marshall Islands','Micronesia','Nauru','New Zealand','Palau',
            'Papua New Guinea','Samoa','Solomon Islands','Tonga','Tuvalu','Vanuatu') THEN 'Australia_and_Oceania'
    END AS Region,
    country,
    SUM(subscribers) AS total_subscribers,
    SUM(uploads) AS total_uploads,
    SUM([video_views]) AS total_views
    
FROM my_table
group by country

"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                    Region      country  total_subscribers  total_uploads  \
# 0                    Asia  Afghanistan           20400000              0
# 1                  Europe      Andorra           15100000            159
# 2           South_America    Argentina          328500000          17240
# 3   Australia_and_Oceania    Australia          154400000           7179
# 4                    Asia   Bangladesh           13900000              6
# 5           North_America     Barbados           41900000             84
# 6           South_America       Brazil         1207300000         168178
# 7           North_America       Canada          363900000          46745
# 8           South_America        Chile           87200000           6771
# 9                    Asia        China           17600000            128
# 10          South_America     Colombia          264500000          10779
# 11          North_America         Cuba           46300000              1
# 12          South_America      Ecuador           27700000           1934
# 13                 Africa        Egypt           30600000           5936
# 14          North_America  El Salvador           46100000            543
# 15                 Europe      Finland           13200000            172
# 16                 Europe       France           83900000           2227
# 17                 Europe      Germany          116400000           6743
# 18                   Asia        India         4310600000        3728212
# 19                   Asia    Indonesia          534100000         678321
# 20                   Asia         Iraq           30200000           3860
# 21                 Europe        Italy           39400000           1805
# 22                   Asia        Japan          189100000          18856
# 23                   Asia       Jordan           67000000           6667
# 24                   Asia       Kuwait           30500000            641
#
#       total_views
# 0     13397000296
# 1      2400037562
# 2    194415353954
# 3     65389465134
# 4     12129583055
# 5     22477745835
# 6    478768256178
# 7    191320574087
# 8     29347556577
# 9      2977741577
# 10   154197807651
# 11    22936630813
# 12     5492461363
# 13     9824740566
# 14    10323391593
# 15     2036408398
# 16    30557640065
# 17    54232247240
# 18  2281048375204
# 19   151010669055
# 20    17007652162
# 21    19894897856
# 22    85682017434
# 23    53090079884
# 24     4521573939

# %%
# close the engine
engine.dispose()
