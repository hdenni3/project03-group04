# %%
# dependencies
import chardet
import pandas as pd
import os 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# API
import requests
import json

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

# %%
# Load in file
# Store filepath in a variable
YOUTUBE_PATH = "Resources/global_youtube_stats.csv"

# %%
with open(YOUTUBE_PATH, 'rb') as csv_file:
    raw_content = csv_file.read()
    chardet_result = chardet.detect(raw_content)
print(chardet_result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7289153199558486, 'language': ''}

# %%
# Read and display the CSV with Pandas
df = pd.read_csv(YOUTUBE_PATH, encoding=chardet_result['encoding'])
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
#  10  video_views_rank                         994 non-null    float64
#  11  country_rank                             879 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  995 non-null    float64
#  15  highest_monthly_earnings                 995 non-null    float64
#  16  lowest_yearly_earnings                   995 non-null    float64
#  17  highest_yearly_earnings                  995 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    float64
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  872 non-null    float64
#  23  Population                               872 non-null    float64
#  24  Unemployment rate                        872 non-null    float64
#  25  Urban_population                         872 non-null    float64
#  26  Latitude                                 872 non-null    float64
#  27  Longitude                                872 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 217.8+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 554 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     554 non-null    int64
#  1   Youtuber                                 554 non-null    object
#  2   subscribers                              554 non-null    int64
#  3   video views                              554 non-null    float64
#  4   category                                 554 non-null    object
#  5   Title                                    554 non-null    object
#  6   uploads                                  554 non-null    int64
#  7   Country                                  554 non-null    object
#  8   Abbreviation                             554 non-null    object
#  9   channel_type                             554 non-null    object
#  10  video_views_rank                         554 non-null    float64
#  11  country_rank                             554 non-null    float64
#  12  channel_type_rank                        554 non-null    float64
#  13  video_views_for_the_last_30_days         554 non-null    float64
#  14  lowest_monthly_earnings                  554 non-null    float64
#  15  highest_monthly_earnings                 554 non-null    float64
#  16  lowest_yearly_earnings                   554 non-null    float64
#  17  highest_yearly_earnings                  554 non-null    float64
#  18  subscribers_for_last_30_days             554 non-null    float64
#  19  created_year                             554 non-null    float64
#  20  created_month                            554 non-null    object
#  21  created_date                             554 non-null    float64
#  22  Gross tertiary education enrollment (%)  554 non-null    float64
#  23  Population                               554 non-null    float64
#  24  Unemployment rate                        554 non-null    float64
#  25  Urban_population                         554 non-null    float64
#  26  Latitude                                 554 non-null    float64
#  27  Longitude                                554 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 125.5+ KB

# %%
# pd.set_option('display.max_rows', None)  # Set the option to display all rows
#print(df)

# %%
# Assuming your DataFrame is named df
# Rename specific columns
cleaned_df = df.rename(columns={
    'Gross tertiary education enrollment (%)': 'gross education enrollment percentage',
    'Youtuber': 'youtuber',
    'Title': 'title',
    'Abbreviation': 'abbreviation',
    'Country' : 'country',
    'Population': 'population',
    'Unemployment rate': 'unemployment rate',
    'Urban_population' : 'urban_population',
    'Latitude' : 'latitude',
    'Longitude' : 'longitude',
    'video views' : 'video_views'
    })

# Display the DataFrame with renamed columns
cleaned_df.head()
# Out:
#    rank                    youtuber  subscribers   video_views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 8     9                 Like Nastya    106000000  9.047906e+10
#
#          category                       title  uploads        country  \
# 0           Music                    T-Series    20082          India
# 2   Entertainment                     MrBeast      741  United States
# 3       Education  Cocomelon - Nursery Rhymes      966  United States
# 4           Shows                   SET India   116536          India
# 8  People & Blogs            Like Nastya Vlog      493         Russia
#
#   abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
# 8           RU         People  ...                      100000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
# 8        2016.0            Jan          14.0
#
#    gross education enrollment percentage    population  unemployment rate  \
# 0                                   28.1  1.366418e+09               5.36
# 2                                   88.2  3.282395e+08              14.70
# 3                                   88.2  3.282395e+08              14.70
# 4                                   28.1  1.366418e+09               5.36
# 8                                   81.9  1.443735e+08               4.59
#
#    urban_population   latitude   longitude
# 0       471031528.0  20.593684   78.962880
# 2       270663028.0  37.090240  -95.712891
# 3       270663028.0  37.090240  -95.712891
# 4       471031528.0  20.593684   78.962880
# 8       107683889.0  61.524010  105.318756
#
# [5 rows x 28 columns]

# %%
# Specify the URI for the cleaned database
db_uri = 'sqlite:///data.db'

# Create an engine using the specified URI
engine = create_engine(db_uri)

# Write the cleaned DataFrame to a SQLite database table named 'my_table'
cleaned_df.to_sql('my_table', engine, if_exists='replace', index=False)

# Confirm that the data has been successfully written to the database
df_from_db = pd.read_sql('my_table', engine)
print(df_from_db)
# Out:
#      rank                    youtuber  subscribers   video_views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       3                     MrBeast    166000000  2.836884e+10
# 2       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 3       5                   SET India    159000000  1.480000e+11
# 4       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 549   990                   Migos ATL     12400000  6.993406e+09
# 550   991               Natan por Aï¿     12300000  9.029610e+09
# 551   992    Free Fire India Official     12300000  1.674410e+09
# 552   994                 RobTopGames     12300000  3.741235e+08
# 553   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       title  uploads        country  \
# 0             Music                    T-Series    20082          India
# 1     Entertainment                     MrBeast      741  United States
# 2         Education  Cocomelon - Nursery Rhymes      966  United States
# 3             Shows                   SET India   116536          India
# 4    People & Blogs            Like Nastya Vlog      493         Russia
# ..              ...                         ...      ...            ...
# 549           Music                   Migos ATL       99  United States
# 550          Sports               Natan por Aï¿     1200         Brazil
# 551  People & Blogs    Free Fire India Official     1500          India
# 552          Gaming                 RobTopGames       39         Sweden
# 553          Comedy                Make Joke Of       62          India
#
#     abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US  Entertainment  ...                     8000000.0
# 2             US      Education  ...                     1000000.0
# 3             IN  Entertainment  ...                     1000000.0
# 4             RU         People  ...                      100000.0
# ..           ...            ...  ...                           ...
# 549           US  Entertainment  ...                      100000.0
# 550           BR  Entertainment  ...                      700000.0
# 551           IN          Games  ...                      300000.0
# 552           SE          Games  ...                      100000.0
# 553           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2012.0            Feb          20.0
# 2          2006.0            Sep           1.0
# 3          2006.0            Sep          20.0
# 4          2016.0            Jan          14.0
# ..            ...            ...           ...
# 549        2012.0            Jan          17.0
# 550        2017.0            Feb          12.0
# 551        2018.0            Sep          14.0
# 552        2012.0            May           9.0
# 553        2017.0            Aug           1.0
#
#      gross education enrollment percentage    population  unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     28.1  1.366418e+09               5.36
# 4                                     81.9  1.443735e+08               4.59
# ..                                     ...           ...                ...
# 549                                   88.2  3.282395e+08              14.70
# 550                                   51.3  2.125594e+08              12.08
# 551                                   28.1  1.366418e+09               5.36
# 552                                   67.0  1.028545e+07               6.48
# 553                                   28.1  1.366418e+09               5.36
#
#      urban_population   latitude   longitude
# 0         471031528.0  20.593684   78.962880
# 1         270663028.0  37.090240  -95.712891
# 2         270663028.0  37.090240  -95.712891
# 3         471031528.0  20.593684   78.962880
# 4         107683889.0  61.524010  105.318756
# ..                ...        ...         ...
# 549       270663028.0  37.090240  -95.712891
# 550       183241641.0 -14.235004  -51.925280
# 551       471031528.0  20.593684   78.962880
# 552         9021165.0  60.128161   18.643501
# 553       471031528.0  20.593684   78.962880
#
# [554 rows x 28 columns]

# %%
# INSPECT to confirm existence
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# Collect the names of tables within the database
tables = inspector.get_table_names()

print(tables)
# Out:
# ['my_table']

# %%
query = """ SELECT rank, Youtuber, subscribers
FROM my_table
ORDER BY subscribers DESC
LIMIT 25 """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                     youtuber  subscribers
# 0      1                                     T-Series    245000000
# 1      3                                      MrBeast    166000000
# 2      4                   Cocomelon - Nursery Rhymes    162000000
# 3      5                                    SET India    159000000
# 4      9                                  Like Nastya    106000000
# 5     10                                Vlad and Niki     98900000
# 6     11                            Zee Music Company     96700000
# 7     12                                          WWE     96000000
# 8     14                                    BLACKPINK     89800000
# 9     16                                     Sony SAB     83000000
# 10    18                                    BANGTANTV     75600000
# 11    20                                Justin Bieber     71600000
# 12    21                                  HYBE LABELS     71300000
# 13    22                                       Zee TV     70500000
# 14    23  Pinkfong Baby Shark - Kids' Songs & Stories     68200000
# 15    25        ChuChu TV Nursery Rhymes & Kids Songs     65900000
# 16    26                         Shemaroo Filmi Gaane     65600000
# 17    27                                    Colors TV     64600000
# 18    29                                 Dude Perfect     59500000
# 19    30                                   Movieclips     59500000
# 20    31                                Tips Official     59300000
# 21    32                            El Reino Infantil     58400000
# 22    33                                   Wave Music     58000000
# 23    34                                      Aaj Tak     57600000
# 24    35                             Sony Music India     57200000

# %%
#WHAT ARE THE TOP 10/25 YOUTUBE CHANNELS BY THE NUMBER OF SUBSCRIBERS AND VIDEO VIEWS
# 1A Define the SQL query top channels by subscribers
query = """
SELECT  Subscribers, country, channel_type
FROM my_table
GROUP BY channel_type
ORDER BY Subscribers DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     subscribers        country   channel_type
# 0     245000000          India          Music
# 1     166000000  United States  Entertainment
# 2     162000000  United States      Education
# 3     106000000         Russia         People
# 4      96000000  United States         Sports
# 5      59500000  United States           Film
# 6      57600000          India           News
# 7      48100000          Chile          Games
# 8      43500000       Colombia          Howto
# 9      39200000          India         Comedy
# 10     38600000  United States      Nonprofit
# 11     31700000          India           Tech
# 12     23700000  United States        Animals
# 13     14900000          Japan          Autos

# %%
# 1B Define the SQL query top channels by views
query = """
SELECT Rank, Youtuber, video_views, subscribers, country, channel_type
FROM my_table
GROUP BY channel_type
ORDER BY video_views DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                    youtuber   video_views  subscribers  \
# 0      1                    T-Series  2.280000e+11    245000000
# 1      4  Cocomelon - Nursery Rhymes  1.640000e+11    162000000
# 2      9                 Like Nastya  9.047906e+10    106000000
# 3     12                         WWE  7.742847e+10     96000000
# 4     30                  Movieclips  5.931647e+10     59500000
# 5      3                     MrBeast  2.836884e+10    166000000
# 6     64                     Shakira  2.756876e+10     43500000
# 7     34                     Aaj Tak  2.530775e+10     57600000
# 8    276            That Little Puff  2.028969e+10     23700000
# 9     45                 JuegaGerman  1.463171e+10     48100000
# 10   703                  Bayashi TV  8.615619e+09     14900000
# 11    85                  TEDx Talks  7.339333e+09     38600000
# 12   144           MR. INDIAN HACKER  5.711208e+09     31700000
# 13    79                 CarryMinati  3.294013e+09     39200000
#
#           country   channel_type
# 0           India          Music
# 1   United States      Education
# 2          Russia         People
# 3   United States         Sports
# 4   United States           Film
# 5   United States  Entertainment
# 6        Colombia          Howto
# 7           India           News
# 8   United States        Animals
# 9           Chile          Games
# 10          Japan          Autos
# 11  United States      Nonprofit
# 12          India           Tech
# 13          India         Comedy

# %%
#WHAT ARE THE TOP 10/25 YOUTUBE CHANNELS BY COUNTRY


# 2 Define the SQL query top channels by country
query = """
SELECT Rank, Youtuber, subscribers, video_views, country, channel_type, category
FROM my_table
GROUP BY country
ORDER BY channel_type DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                       youtuber  subscribers  \
# 0    424                                           FIFA     19400000
# 1    479                                 How Ridiculous     18000000
# 2     77                                 shfa2 - ï¿½ï¿½     39700000
# 3      9                                    Like Nastya    106000000
# 4     72                                Kimberly Loaiza     41300000
# 5     51                                             A4     46300000
# 6     40                                     Ed Sheeran     53500000
# 7    260                                    netd mï¿½ï¿     24100000
# 8     14                                      BLACKPINK     89800000
# 9    900                                      DJ Khaled     13100000
# 10   168                               Spinnin' Records     30100000
# 11   166  ýýýýýýýý ýýýýýýýý ýýýýýýýýýý | toyoraljanahtv     30200000
# 12     1                                       T-Series    245000000
# 13   316                                   Smile Family     22300000
# 14    20                                  Justin Bieber     71600000
# 15    70                                        Rihanna     41900000
# 16    32                              El Reino Infantil     58400000
# 17   638      ýýýýýýýý ýýýýýýýýýýýýýý ýýýý 5 ýýýýýýýýýý     15500000
# 18    64                                        Shakira     43500000
# 19   508                               ýýýýýýýýý Liziqi     17600000
# 20   994                                    RobTopGames     12300000
# 21    82                                      Mikecrack     39100000
# 22    86                                           shfa     38400000
# 23    53                                     Fernanfloo     46100000
# 24    45                                    JuegaGerman     48100000
#
#      video_views               country channel_type        category
# 0   5.529132e+09           Switzerland       Sports          Sports
# 1   9.601137e+09             Australia       Sports          Sports
# 2   2.388482e+10  United Arab Emirates       People  People & Blogs
# 3   9.047906e+10                Russia       People  People & Blogs
# 4   5.603112e+09                Mexico       People  People & Blogs
# 5   2.293663e+10                  Cuba       People          Gaming
# 6   3.036768e+10        United Kingdom        Music           Music
# 7   5.610609e+10                Turkey        Music           Music
# 8   3.214460e+10           South Korea        Music  People & Blogs
# 9   6.637821e+09                 Samoa        Music           Music
# 10  1.960701e+10           Netherlands        Music           Music
# 11  2.768496e+10                Jordan        Music   Entertainment
# 12  2.280000e+11                 India        Music           Music
# 13  8.663830e+09                France        Music  People & Blogs
# 14  3.060812e+10                Canada        Music           Music
# 15  2.247775e+10              Barbados        Music   Entertainment
# 16  5.727163e+10             Argentina        Music           Music
# 17  4.499827e+09                 Egypt        Howto   Howto & Style
# 18  2.756876e+10              Colombia        Howto  People & Blogs
# 19  2.977742e+09                 China        Howto   Howto & Style
# 20  3.741235e+08                Sweden        Games          Gaming
# 21  1.611818e+10                 Spain        Games          Gaming
# 22  2.152812e+10          Saudi Arabia        Games  People & Blogs
# 23  1.032339e+10           El Salvador        Games          Gaming
# 24  1.463171e+10                 Chile        Games          Gaming

# %%
#3 WHAT ARE THE TOP 10/25 YOUTUBE CHANNELS BY THE NUMBER OF VIEWS


query = """SELECT Youtuber, video_views
FROM my_table
ORDER BY video_views DESC
LIMIT 10"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                      youtuber   video_views
# 0                    T-Series  2.280000e+11
# 1  Cocomelon - Nursery Rhymes  1.640000e+11
# 2                   SET India  1.480000e+11
# 3                    Sony SAB  1.010000e+11
# 4                 Like Nastya  9.047906e+10
# 5                         WWE  7.742847e+10
# 6               Vlad and Niki  7.718017e+10
# 7                      Zee TV  7.313905e+10
# 8                   Colors TV  6.151091e+10
# 9                  Movieclips  5.931647e+10

# %%
# 4WHAT CATEGORIES WILL GET THE MOST VIEWS
# Define the SQL query top channels by country
query = """
SELECT rank, youtuber, subscribers, channel_type, category, country, SUM(video_views) AS total_views
FROM my_table
GROUP BY category
ORDER BY video_views DESC
LIMIT 25
"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                    youtuber  subscribers   channel_type  \
# 0      1                    T-Series    245000000          Music
# 1      4  Cocomelon - Nursery Rhymes    162000000      Education
# 2      5                   SET India    159000000  Entertainment
# 3      9                 Like Nastya    106000000         People
# 4     12                         WWE     96000000         Sports
# 5     30                  Movieclips     59500000           Film
# 6      3                     MrBeast    166000000  Entertainment
# 7     34                     Aaj Tak     57600000           News
# 8    276            That Little Puff     23700000        Animals
# 9     71                Ishtar Music     41400000          Music
# 10    45                 JuegaGerman     48100000          Games
# 11   271                 Troom Troom     23800000          Howto
# 12   183               Aditya Movies     28400000           Film
# 13   334                DUDU e CAROL     21600000  Entertainment
# 14    85                  TEDx Talks     38600000      Nonprofit
# 15   144           MR. INDIAN HACKER     31700000           Tech
# 16    79                 CarryMinati     39200000         Comedy
#
#                  category        country   total_views
# 0                   Music          India  1.937407e+12
# 1               Education  United States  6.107155e+11
# 2                   Shows          India  4.379051e+11
# 3          People & Blogs         Russia  7.634447e+11
# 4                  Sports  United States  1.320809e+11
# 5        Film & Animation  United States  3.899961e+11
# 6           Entertainment  United States  1.813469e+12
# 7         News & Politics          India  2.129565e+11
# 8          Pets & Animals  United States  3.490263e+10
# 9                Trailers          India  3.326272e+10
# 10                 Gaming          Chile  3.893691e+11
# 11          Howto & Style  United States  5.870816e+10
# 12                 Movies          India  1.538326e+10
# 13       Autos & Vehicles         Brazil  1.500346e+10
# 14  Nonprofits & Activism  United States  1.086291e+10
# 15   Science & Technology          India  3.573713e+10
# 16                 Comedy          India  3.695646e+11

# %%
# 5 WHICH CHANNELS HAVE THE HIGHEST TOTAL VIDEO VIEWS?
# Define the SQL query top channels by country
query = """
SELECT channel_type, SUM(video_views) AS total_views
FROM my_table
GROUP BY Youtuber
ORDER BY total_views DESC;

"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#      channel_type   total_views
# 0           Music  2.280000e+11
# 1       Education  1.640000e+11
# 2   Entertainment  1.480000e+11
# 3   Entertainment  1.010000e+11
# 4          People  9.047906e+10
# 5          Sports  7.742847e+10
# 6   Entertainment  7.718017e+10
# 7   Entertainment  7.313905e+10
# 8   Entertainment  6.151091e+10
# 9            Film  5.931647e+10
# 10          Music  5.785629e+10
# 11          Music  5.727163e+10
# 12          Music  5.610609e+10
# 13  Entertainment  5.529984e+10
# 14  Entertainment  5.029254e+10
# 15      Education  4.575785e+10
# 16      Education  4.490090e+10
# 17  Entertainment  4.113905e+10
# 18          Music  4.060202e+10
# 19      Education  3.945082e+10
# 20      Education  3.884323e+10
# 21  Entertainment  3.793978e+10
# 22      Education  3.645873e+10
# 23  Entertainment  3.613123e+10
# 24          Music  3.530224e+10

# %%
# 6WHAT ARE THE TOP 10/25 YOUTUBE CHANNELS BY UPLOAD

query = """
SELECT Youtuber, uploads
FROM my_table
ORDER BY uploads DESC
""";

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(100)
# Out:
#                  youtuber  uploads
# 0                ABP NEWS   301308
# 1     GMA Integrated News   296272
# 2         TV9 Bharatvarsh   293516
# 3                 Aaj Tak   283775
# 4                 IndiaTV   273255
# ..                    ...      ...
# 95               Codiscos     7356
# 96      Prime Video India     7090
# 97   Just For Laughs Gags     6916
# 98  ýýýýýýTwinsFromRussia     6888
# 99                  Tilak     6672
#
# [100 rows x 2 columns]

# %%
#How do channels in different categories compare in terms of average views and earnings, by country?

query = """ SELECT 
    rank,
    Youtuber,
    lowest_monthly_earnings,
    highest_monthly_earnings,
    lowest_yearly_earnings,
    highest_yearly_earnings
FROM my_table
WHERE rank <= 25
ORDER BY highest_yearly_earnings DESC"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)How do channels in different categories
compare in terms of average views and
earnings, by country?
# Out:
#     rank                                     youtuber  \
# 0      1                                     T-Series
# 1      4                   Cocomelon - Nursery Rhymes
# 2      5                                    SET India
# 3     22                                       Zee TV
# 4     16                                     Sony SAB
# 5      3                                      MrBeast
# 6     11                            Zee Music Company
# 7     12                                          WWE
# 8     21                                  HYBE LABELS
# 9     10                                Vlad and Niki
# 10    14                                    BLACKPINK
# 11    23  Pinkfong Baby Shark - Kids' Songs & Stories
# 12    25        ChuChu TV Nursery Rhymes & Kids Songs
# 13    20                                Justin Bieber
# 14    18                                    BANGTANTV
# 15     9                                  Like Nastya
#
#     lowest_monthly_earnings  highest_monthly_earnings  lowest_yearly_earnings  \
# 0                  564600.0                 9000000.0               6800000.0
# 1                  493800.0                 7900000.0               5900000.0
# 2                  455900.0                 7300000.0               5500000.0
# 3                  426800.0                 6800000.0               5100000.0
# 4                  414300.0                 6600000.0               5000000.0
# 5                  337000.0                 5400000.0               4000000.0
# 6                  200900.0                 3200000.0               2400000.0
# 7                  178700.0                 2900000.0               2100000.0
# 8                  149500.0                 2400000.0               1800000.0
# 9                  145100.0                 2300000.0               1700000.0
# 10                 124700.0                 2000000.0               1500000.0
# 11                 118300.0                 1900000.0               1400000.0
# 12                 105100.0                 1700000.0               1300000.0
# 13                  44100.0                  705300.0                529000.0
# 14                  42100.0                  673200.0                504900.0
# 15                  12200.0                  195800.0                146800.0
#
#     highest_yearly_earnings
# 0               108400000.0
# 1                94800000.0
# 2                87500000.0
# 3                81900000.0
# 4                79600000.0
# 5                64700000.0
# 6                38600000.0
# 7                34300000.0
# 8                28700000.0
# 9                27900000.0
# 10               23900000.0
# 11               22700000.0
# 12               20200000.0
# 13                8500000.0
# 14                8100000.0
# 15                2300000.0

# %%
# Which category has the most channels in the top 100 by subscribers?

query = """ SELECT category, COUNT(*) AS Channel_Count
FROM my_table
WHERE rank <= 100
GROUP BY category
ORDER BY Channel_Count DESC
LIMIT 10"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#            category  Channel_Count
# 0             Music             24
# 1     Entertainment             15
# 2    People & Blogs              9
# 3         Education              7
# 4             Shows              5
# 5            Gaming              4
# 6  Film & Animation              3
# 7          Trailers              2
# 8            Sports              2
# 9            Comedy              2

# %%
#How do YouTube channels from different countries compare in terms of average subscribers and views?
query = """ SELECT 
    created_year,
    AVG(subscribers) AS avg_subscriber_count,
    AVG(video_views) AS avg_video_views
FROM my_table
GROUP BY created_year
ORDER BY created_year"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     created_year  avg_subscriber_count  avg_video_views
# 0         1970.0          3.630000e+07     3.010785e+09
# 1         2005.0          2.695714e+07     1.707301e+10
# 2         2006.0          3.769318e+07     2.576865e+10
# 3         2007.0          2.997143e+07     1.862669e+10
# 4         2008.0          2.571379e+07     1.637227e+10
# 5         2009.0          2.641000e+07     1.362201e+10
# 6         2010.0          1.990000e+07     1.094920e+10
# 7         2011.0          2.265833e+07     1.200317e+10
# 8         2012.0          2.619512e+07     1.168654e+10
# 9         2013.0          2.457234e+07     1.119854e+10
# 10        2014.0          2.204545e+07     1.121199e+10
# 11        2015.0          2.120208e+07     9.019076e+09
# 12        2016.0          2.529565e+07     1.165980e+10
# 13        2017.0          1.911351e+07     7.048707e+09
# 14        2018.0          2.531176e+07     1.437037e+10
# 15        2019.0          1.678000e+07     9.628934e+09
# 16        2020.0          1.990000e+07     1.383509e+10
# 17        2021.0          1.860909e+07     1.292920e+10
# 18        2022.0          1.310000e+07     2.182651e+09

# %%
#What are the oldest YouTube channels in the top 100 by subscribers? globally?
query = """SELECT rank, Youtuber, created_year, created_month, created_date
FROM my_table
WHERE rank <= 100
ORDER BY created_year, created_month, created_date
LIMIT 100"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                         youtuber  created_year created_month  \
# 0     22                           Zee TV        2005.0           Dec
# 1     70                          Rihanna        2005.0           Nov
# 2     64                          Shakira        2005.0           Oct
# 3     71                     Ishtar Music        2005.0           Sep
# 4     30                       Movieclips        2006.0           Apr
# 5     40                       Ed Sheeran        2006.0           Aug
# 6     47                       Get Movies        2006.0           Dec
# 7     38                              YRF        2006.0           Jun
# 8     51                               A4        2006.0           Mar
# 9      1                         T-Series        2006.0           Mar
# 10    55                      Felipe Neto        2006.0           May
# 11     4       Cocomelon - Nursery Rhymes        2006.0           Sep
# 12    81  Super Simple Songs - Kids Songs        2006.0           Sep
# 13    98                       Bruno Mars        2006.0           Sep
# 14     5                        SET India        2006.0           Sep
# 15    42                     Taylor Swift        2006.0           Sep
# 16    16                         Sony SAB        2007.0           Aug
# 17    36                      EminemMusic        2007.0           Feb
# 18    20                    Justin Bieber        2007.0           Jan
# 19    43                    Ariana Grande        2007.0           Jan
# 20    12                              WWE        2007.0           May
# 21    31                    Tips Official        2007.0           May
# 22    48                         Shemaroo        2007.0           Sep
# 23    57                      HAR PAL GEO        2008.0           Jan
# 24    61            ABS-CBN Entertainment        2008.0           Jul
#
#     created_date
# 0           11.0
# 1            6.0
# 2           16.0
# 3           22.0
# 4           28.0
# 5            8.0
# 6           16.0
# 7            7.0
# 8           11.0
# 9           13.0
# 10          16.0
# 11           1.0
# 12           8.0
# 13          19.0
# 14          20.0
# 15          20.0
# 16           4.0
# 17           9.0
# 18          15.0
# 19          22.0
# 20          11.0
# 21          22.0
# 22           1.0
# 23           2.0
# 24          16.0

# %%
# Which country has the most YouTube channels in the top 100 globally?

query = """ SELECT 
    Country, 
    COUNT(Youtuber) AS channel_count
FROM 
    my_table
GROUP BY 
    Country"""
    
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#         country  channel_count
# 0     Argentina             11
# 1     Australia              2
# 2      Barbados              1
# 3        Brazil             33
# 4        Canada              6
# 5         Chile              3
# 6         China              1
# 7      Colombia              9
# 8          Cuba              1
# 9       Ecuador              2
# 10        Egypt              2
# 11  El Salvador              1
# 12       France              4
# 13      Germany              4
# 14        India            139
# 15    Indonesia             19
# 16        Italy              2
# 17        Japan              4
# 18       Jordan              3
# 19       Kuwait              1
# 20       Latvia              1
# 21     Malaysia              1
# 22       Mexico             17
# 23  Netherlands              2
# 24     Pakistan              4

# %%
query = """ SELECT Youtuber, AVG(subscribers_for_last_30_days) AS avg_subscribers_per_month
FROM my_table
GROUP BY Youtuber"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                                            youtuber  avg_subscribers_per_month
# 0                                   123 GO! Spanish                   100000.0
# 1                              5-Minute Crafts PLAY                   100000.0
# 2                                           50 Cent                   100000.0
# 3                                           7clouds                   300000.0
# 4                     A2 Motivation by Arvind Arora                   200000.0
# 5                                                A4                       10.0
# 6                                          ABC News                   100000.0
# 7                                          ABP NEWS                   400000.0
# 8                             ABS-CBN Entertainment                   300000.0
# 9                                      ABS-CBN News                   100000.0
# 10  AMARINTV : ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½                   200000.0
# 11                                   ARY Digital HD                   900000.0
# 12                                 Aadishakti Films                   200000.0
# 13                                          Aaj Tak                   500000.0
# 14                                          AboFlah                  1300000.0
# 15                                           Acenix                   200000.0
# 16                                           Adam W                   200000.0
# 17                                            Adele                   100000.0
# 18                                        AdeleVEVO                   100000.0
# 19                                    Aditya Movies                   500000.0
# 20                                          Airrack                   300000.0
# 21                                             Akon                   100000.0
# 22                         AlArabiya ï¿½ï¿½ï¿½ï¿½ï¿                   100000.0
# 23                                 Alan Chikin Chow                  1300000.0
# 24                                       Alejo Igoa                   600000.0

# %%
#Which channels gained the most subscribers?
query = """ SELECT Youtuber, subscribers_for_last_30_days
FROM my_table
ORDER BY subscribers_for_last_30_days DESC"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                           youtuber  subscribers_for_last_30_days
# 0                          MrBeast                     8000000.0
# 1                     DaFuq!?Boom!                     6700000.0
# 2                    Jess No Limit                     5500000.0
# 3                         T-Series                     2000000.0
# 4                        PANDA BOI                     2000000.0
# 5                   Ricis Official                     1900000.0
# 6                        TheDonato                     1900000.0
# 7                     Topper Guild                     1900000.0
# 8                Infobells - Hindi                     1600000.0
# 9                    Ishaan Ali 11                     1600000.0
# 10                tuzelity SHUFFLE                     1600000.0
# 11                   Ami Rodriguez                     1600000.0
# 12                    Willie Salim                     1600000.0
# 13                      Go Ami Go!                     1500000.0
# 14                      Heroindori                     1400000.0
# 15                     HAR PAL GEO                     1300000.0
# 16                         AboFlah                     1300000.0
# 17                Alan Chikin Chow                     1300000.0
# 18                  LeoNata Family                     1300000.0
# 19  Pokï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½                     1300000.0
# 20                        StarPlus                     1200000.0
# 21                    Beast Reacts                     1200000.0
# 22                       dednahype                     1200000.0
# 23               Prime Video India                     1200000.0
# 24                        _vector_                     1200000.0

# %%
#Which channels had the highest video views?
query = """ SELECT Youtuber, video_views
FROM my_table
ORDER BY video_views DESC """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                                          youtuber   video_views
# 0                                        T-Series  2.280000e+11
# 1                      Cocomelon - Nursery Rhymes  1.640000e+11
# 2                                       SET India  1.480000e+11
# 3                                        Sony SAB  1.010000e+11
# 4                                     Like Nastya  9.047906e+10
# 5                                             WWE  7.742847e+10
# 6                                   Vlad and Niki  7.718017e+10
# 7                                          Zee TV  7.313905e+10
# 8                                       Colors TV  6.151091e+10
# 9                                      Movieclips  5.931647e+10
# 10                              Zee Music Company  5.785629e+10
# 11                              El Reino Infantil  5.727163e+10
# 12                                    netd mï¿½ï¿  5.610609e+10
# 13                                   Ryan's World  5.529984e+10
# 14                          ABS-CBN Entertainment  5.029254e+10
# 15          ChuChu TV Nursery Rhymes & Kids Songs  4.575785e+10
# 16                Super Simple Songs - Kids Songs  4.490090e+10
# 17                                    HAR PAL GEO  4.113905e+10
# 18                                     Wave Music  4.060202e+10
# 19  Little Baby Bum - Nursery Rhymes & Kids Songs  3.945082e+10
# 20    Pinkfong Baby Shark - Kids' Songs & Stories  3.884323e+10
# 21                                 ARY Digital HD  3.793978e+10
# 22                     ýýýýýýýý ýý ýýýýýýýýýýýýýý  3.645873e+10
# 23                              WorkpointOfficial  3.613123e+10
# 24                                            YRF  3.530224e+10

# %%
#What are the estimated monthly and yearly earnings for the top 25 YouTube channels?
query = """ SELECT Rank, Youtuber, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings,
       lowest_monthly_earnings * 12 AS estimated_yearly_low,
       highest_monthly_earnings * 12 AS estimated_yearly_high
FROM my_table
ORDER BY Rank
LIMIT 25"""

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                     youtuber  \
# 0      1                                     T-Series
# 1      3                                      MrBeast
# 2      4                   Cocomelon - Nursery Rhymes
# 3      5                                    SET India
# 4      9                                  Like Nastya
# 5     10                                Vlad and Niki
# 6     11                            Zee Music Company
# 7     12                                          WWE
# 8     14                                    BLACKPINK
# 9     16                                     Sony SAB
# 10    18                                    BANGTANTV
# 11    20                                Justin Bieber
# 12    21                                  HYBE LABELS
# 13    22                                       Zee TV
# 14    23  Pinkfong Baby Shark - Kids' Songs & Stories
# 15    25        ChuChu TV Nursery Rhymes & Kids Songs
# 16    26                         Shemaroo Filmi Gaane
# 17    27                                    Colors TV
# 18    29                                 Dude Perfect
# 19    30                                   Movieclips
# 20    31                                Tips Official
# 21    32                            El Reino Infantil
# 22    33                                   Wave Music
# 23    34                                      Aaj Tak
# 24    35                             Sony Music India
#
#     lowest_monthly_earnings  highest_monthly_earnings  lowest_yearly_earnings  \
# 0                  564600.0                 9000000.0               6800000.0
# 1                  337000.0                 5400000.0               4000000.0
# 2                  493800.0                 7900000.0               5900000.0
# 3                  455900.0                 7300000.0               5500000.0
# 4                   12200.0                  195800.0                146800.0
# 5                  145100.0                 2300000.0               1700000.0
# 6                  200900.0                 3200000.0               2400000.0
# 7                  178700.0                 2900000.0               2100000.0
# 8                  124700.0                 2000000.0               1500000.0
# 9                  414300.0                 6600000.0               5000000.0
# 10                  42100.0                  673200.0                504900.0
# 11                  44100.0                  705300.0                529000.0
# 12                 149500.0                 2400000.0               1800000.0
# 13                 426800.0                 6800000.0               5100000.0
# 14                 118300.0                 1900000.0               1400000.0
# 15                 105100.0                 1700000.0               1300000.0
# 16                  63700.0                 1000000.0                764900.0
# 17                 296900.0                 4800000.0               3600000.0
# 18                  35300.0                  564800.0                423600.0
# 19                  28700.0                  458700.0                344000.0
# 20                 105700.0                 1700000.0               1300000.0
# 21                 153000.0                 2400000.0               1800000.0
# 22                  58000.0                  928100.0                696100.0
# 23                 115300.0                 1800000.0               1400000.0
# 24                  64800.0                 1000000.0                777900.0
#
#     highest_yearly_earnings  estimated_yearly_low  estimated_yearly_high
# 0               108400000.0             6775200.0            108000000.0
# 1                64700000.0             4044000.0             64800000.0
# 2                94800000.0             5925600.0             94800000.0
# 3                87500000.0             5470800.0             87600000.0
# 4                 2300000.0              146400.0              2349600.0
# 5                27900000.0             1741200.0             27600000.0
# 6                38600000.0             2410800.0             38400000.0
# 7                34300000.0             2144400.0             34800000.0
# 8                23900000.0             1496400.0             24000000.0
# 9                79600000.0             4971600.0             79200000.0
# 10                8100000.0              505200.0              8078400.0
# 11                8500000.0              529200.0              8463600.0
# 12               28700000.0             1794000.0             28800000.0
# 13               81900000.0             5121600.0             81600000.0
# 14               22700000.0             1419600.0             22800000.0
# 15               20200000.0             1261200.0             20400000.0
# 16               12200000.0              764400.0             12000000.0
# 17               57000000.0             3562800.0             57600000.0
# 18                6800000.0              423600.0              6777600.0
# 19                5500000.0              344400.0              5504400.0
# 20               20300000.0             1268400.0             20400000.0
# 21               29400000.0             1836000.0             28800000.0
# 22               11100000.0              696000.0             11137200.0
# 23               22100000.0             1383600.0             21600000.0
# 24               12400000.0              777600.0             12000000.0

# %%
#Which channels have the highest estimated earnings?
query = """ SELECT Youtuber, 
       ((lowest_monthly_earnings + highest_monthly_earnings) / 2) * 12 AS estimated_yearly_earnings
FROM my_table
ORDER BY estimated_yearly_earnings DESC """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                        youtuber  estimated_yearly_earnings
# 0                  DaFuq!?Boom!                 58656000.0
# 1                      T-Series                 57387600.0
# 2    Cocomelon - Nursery Rhymes                 50362800.0
# 3                     SET India                 46535400.0
# 4                        Zee TV                 43360800.0
# 5                      StarPlus                 42700800.0
# 6                      Sony SAB                 42085800.0
# 7                   GR6 EXPLODE                 41452200.0
# 8                      ViralHog                 35045400.0
# 9                       MrBeast                 34422000.0
# 10                  HAR PAL GEO                 33805800.0
# 11                    dednahype                 31867200.0
# 12                    PANDA BOI                 31238400.0
# 13                    Colors TV                 30581400.0
# 14               LeoNata Family                 29961000.0
# 15               ARY Digital HD                 29323800.0
# 16                         GH'S                 27421800.0
# 17             Alan Chikin Chow                 26769000.0
# 18                       Sun TV                 24873600.0
# 19             Vijay Television                 22961400.0
# 20                     _vector_                 22955400.0
# 21                      Yoeslan                 22312200.0
# 22            Infobells - Hindi                 21024000.0
# 23                     LankyBox                 21022800.0
# 24  Goldmines Gaane Sune Ansune                 21022200.0

# %%
#How do YouTube channels from different countries compare in terms of average subscribers and views?


query = """ 
SELECT Country, 
       AVG(subscribers) AS avg_subscribers,
       AVG(video_views) AS avg_video_views
FROM my_table
GROUP BY Country
ORDER BY avg_subscribers DESC, avg_video_views DESC """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#                  country  avg_subscribers  avg_video_views
# 0                   Cuba     4.630000e+07     2.293663e+10
# 1            El Salvador     4.610000e+07     1.032339e+10
# 2               Barbados     4.190000e+07     2.247775e+10
# 3            South Korea     4.057500e+07     1.616908e+10
# 4               Pakistan     3.247500e+07     2.716291e+10
# 5              Venezuela     3.120000e+07     9.673649e+09
# 6                 Canada     3.101667e+07     1.904904e+10
# 7                 Kuwait     3.050000e+07     4.521574e+09
# 8                  Chile     2.906667e+07     9.782519e+09
# 9                  India     2.753957e+07     1.539299e+10
# 10                Russia     2.750000e+07     1.756116e+10
# 11         United States     2.539721e+07     1.353575e+10
# 12           Philippines     2.538333e+07     1.936845e+10
# 13             Argentina     2.516364e+07     1.501349e+10
# 14              Colombia     2.495556e+07     1.368188e+10
# 15                Jordan     2.233333e+07     1.769669e+10
# 16           Netherlands     2.195000e+07     1.104398e+10
# 17                Turkey     2.185000e+07     3.244291e+10
# 18              Thailand     2.094615e+07     1.606049e+10
# 19        United Kingdom     2.084615e+07     1.031110e+10
# 20                Brazil     2.070606e+07     8.782897e+09
# 21          Saudi Arabia     2.065000e+07     1.109618e+10
# 22  United Arab Emirates     2.046000e+07     1.021773e+10
# 23                Latvia     2.020000e+07     2.091940e+10
# 24             Indonesia     2.020000e+07     6.639409e+09

# %%
#WHAT ARE THE TOP 10/25 YOUTUBE CHANNELS BY THE NUMBER OF SUBSCRIBERS?

query = """SELECT Rank, Youtuber, subscribers
FROM my_table
ORDER BY subscribers DESC
LIMIT 25 """
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#     rank                                     youtuber  subscribers
# 0      1                                     T-Series    245000000
# 1      3                                      MrBeast    166000000
# 2      4                   Cocomelon - Nursery Rhymes    162000000
# 3      5                                    SET India    159000000
# 4      9                                  Like Nastya    106000000
# 5     10                                Vlad and Niki     98900000
# 6     11                            Zee Music Company     96700000
# 7     12                                          WWE     96000000
# 8     14                                    BLACKPINK     89800000
# 9     16                                     Sony SAB     83000000
# 10    18                                    BANGTANTV     75600000
# 11    20                                Justin Bieber     71600000
# 12    21                                  HYBE LABELS     71300000
# 13    22                                       Zee TV     70500000
# 14    23  Pinkfong Baby Shark - Kids' Songs & Stories     68200000
# 15    25        ChuChu TV Nursery Rhymes & Kids Songs     65900000
# 16    26                         Shemaroo Filmi Gaane     65600000
# 17    27                                    Colors TV     64600000
# 18    29                                 Dude Perfect     59500000
# 19    30                                   Movieclips     59500000
# 20    31                                Tips Official     59300000
# 21    32                            El Reino Infantil     58400000
# 22    33                                   Wave Music     58000000
# 23    34                                      Aaj Tak     57600000
# 24    35                             Sony Music India     57200000

# %%
query = """ SELECT 
    Latitude, 
    Longitude, 
    COUNT(channel_type) AS channel_count
FROM 
    my_table
GROUP BY 
    Latitude, 
    Longitude
ORDER BY 
    channel_count DESC
    """

# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#      latitude   longitude  channel_count
# 0   37.090240  -95.712891            179
# 1   20.593684   78.962880            139
# 2  -14.235004  -51.925280             33
# 3   55.378051   -3.435973             26
# 4   -0.789275  113.921327             19
# 5   23.634501 -102.552784             17
# 6   15.870032  100.992541             13
# 7   61.524010  105.318756             13
# 8  -38.416097  -63.616672             11
# 9   40.463667   -3.749220             11
# 10   4.570868  -74.297333              9
# 11  35.907757  127.766922              8
# 12  12.879721  121.774017              6
# 13  23.885942   45.079162              6
# 14  56.130366 -106.346771              6
# 15  23.424076   53.847818              5
# 16  48.379433   31.165580              5
# 17  30.375321   69.345116              4
# 18  36.204824  138.252924              4
# 19  46.227638    2.213749              4
# 20  51.165691   10.451526              4
# 21 -35.675147  -71.542969              3
# 22  30.585164   36.238414              3
# 23 -25.274398  133.775136              2
# 24  -1.831239  -78.183406              2

# %%
query_highest_views = """
SELECT Youtuber, SUM("video views") AS total_views
FROM youtube_data
GROUP BY Youtuber
ORDER BY total_views DESC;
"""
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#      latitude   longitude  channel_count
# 0   37.090240  -95.712891            179
# 1   20.593684   78.962880            139
# 2  -14.235004  -51.925280             33
# 3   55.378051   -3.435973             26
# 4   -0.789275  113.921327             19
# 5   23.634501 -102.552784             17
# 6   15.870032  100.992541             13
# 7   61.524010  105.318756             13
# 8  -38.416097  -63.616672             11
# 9   40.463667   -3.749220             11
# 10   4.570868  -74.297333              9
# 11  35.907757  127.766922              8
# 12  12.879721  121.774017              6
# 13  23.885942   45.079162              6
# 14  56.130366 -106.346771              6
# 15  23.424076   53.847818              5
# 16  48.379433   31.165580              5
# 17  30.375321   69.345116              4
# 18  36.204824  138.252924              4
# 19  46.227638    2.213749              4
# 20  51.165691   10.451526              4
# 21 -35.675147  -71.542969              3
# 22  30.585164   36.238414              3
# 23 -25.274398  133.775136              2
# 24  -1.831239  -78.183406              2

# %%
query_content_popularity = """SELECT category, SUM("video views") AS total_views, AVG(subscribers_for_last_30_days) AS avg_engagement
FROM youtube_data
GROUP BY category
ORDER BY total_views DESC;
"""
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#      latitude   longitude  channel_count
# 0   37.090240  -95.712891            179
# 1   20.593684   78.962880            139
# 2  -14.235004  -51.925280             33
# 3   55.378051   -3.435973             26
# 4   -0.789275  113.921327             19
# 5   23.634501 -102.552784             17
# 6   15.870032  100.992541             13
# 7   61.524010  105.318756             13
# 8  -38.416097  -63.616672             11
# 9   40.463667   -3.749220             11
# 10   4.570868  -74.297333              9
# 11  35.907757  127.766922              8
# 12  12.879721  121.774017              6
# 13  23.885942   45.079162              6
# 14  56.130366 -106.346771              6
# 15  23.424076   53.847818              5
# 16  48.379433   31.165580              5
# 17  30.375321   69.345116              4
# 18  36.204824  138.252924              4
# 19  46.227638    2.213749              4
# 20  51.165691   10.451526              4
# 21 -35.675147  -71.542969              3
# 22  30.585164   36.238414              3
# 23 -25.274398  133.775136              2
# 24  -1.831239  -78.183406              2

# %%
query_population_correlation = """
SELECT Country, Population, COUNT(Youtuber) AS channel_count
FROM youtube_data
GROUP BY Country;
"""
# Execute the query and read the results into a DataFrame
df = pd.read_sql(text(query), con=engine)
df.head(25)
# Out:
#      latitude   longitude  channel_count
# 0   37.090240  -95.712891            179
# 1   20.593684   78.962880            139
# 2  -14.235004  -51.925280             33
# 3   55.378051   -3.435973             26
# 4   -0.789275  113.921327             19
# 5   23.634501 -102.552784             17
# 6   15.870032  100.992541             13
# 7   61.524010  105.318756             13
# 8  -38.416097  -63.616672             11
# 9   40.463667   -3.749220             11
# 10   4.570868  -74.297333              9
# 11  35.907757  127.766922              8
# 12  12.879721  121.774017              6
# 13  23.885942   45.079162              6
# 14  56.130366 -106.346771              6
# 15  23.424076   53.847818              5
# 16  48.379433   31.165580              5
# 17  30.375321   69.345116              4
# 18  36.204824  138.252924              4
# 19  46.227638    2.213749              4
# 20  51.165691   10.451526              4
# 21 -35.675147  -71.542969              3
# 22  30.585164   36.238414              3
# 23 -25.274398  133.775136              2
# 24  -1.831239  -78.183406              2
